# %% [markdown]
# ##Some advanced maneuvers: Exporting a documents-only network as GEXF and JSON for d3.
#
# This notebook and code require you to install pandas, networkx, and numpy.  You can make a new virtualenv with anaconda:
#
#
#
# or try
# >pip install pandas (it will install numpy too)
# >pip install networkx

# %%
import pandas as pd
import networkx as nx  # http://networkx.github.io/documentation/networkx-1.9/index.html
import numpy as np

# %%
excelcsv = 'files/for_excel.csv'
df = pd.read_csv(excelcsv)

# %%
df
# Out:
#      DocID    Topic  Score                        File     Author
# 0       42  Topic11  0.335  stevenson_treasure_ch1.txt  stevenson
# 1       42  Topic10  0.134  stevenson_treasure_ch1.txt  stevenson
# 2       42  Topic13  0.144  stevenson_treasure_ch1.txt  stevenson
# 3       42   Topic7  0.129  stevenson_treasure_ch1.txt  stevenson
# 4       43  Topic11  0.326  stevenson_treasure_ch2.txt  stevenson
# 5       43  Topic10  0.250  stevenson_treasure_ch2.txt  stevenson
# 6       43   Topic1  0.101  stevenson_treasure_ch2.txt  stevenson
# 7       24   Topic9  0.125   eliot_middlemarch_ch2.txt      eliot
# 8       24  Topic13  0.144   eliot_middlemarch_ch2.txt      eliot
# 9       24   Topic4  0.365   eliot_middlemarch_ch2.txt      eliot
# 10      25   Topic9  0.242  eliot_middlemarch_ch48.txt      eliot
# 11      25  Topic13  0.160  eliot_middlemarch_ch48.txt      eliot
# 12      25   Topic4  0.178  eliot_middlemarch_ch48.txt      eliot
# 13      25   Topic7  0.110  eliot_middlemarch_ch48.txt      eliot
# 14      26   Topic9  0.166  eliot_middlemarch_ch73.txt      eliot
# 15      26  Topic13  0.390  eliot_middlemarch_ch73.txt      eliot
# 16      27   Topic7  0.647     grimms_hanselgretel.txt     grimms
# 17      20  Topic13  0.137    doyle_caseofidentity.txt      doyle
# 18      20   Topic6  0.380    doyle_caseofidentity.txt      doyle
# 19      21   Topic9  0.102   doyle_redheadedleague.txt      doyle
# 20      21  Topic10  0.113   doyle_redheadedleague.txt      doyle
# 21      21   Topic6  0.399   doyle_redheadedleague.txt      doyle
# 22      22  Topic10  0.122    doyle_scandalbohemia.txt      doyle
# 23      22  Topic13  0.121    doyle_scandalbohemia.txt      doyle
# 24      22   Topic7  0.113    doyle_scandalbohemia.txt      doyle
# 25      22   Topic6  0.321    doyle_scandalbohemia.txt      doyle
# 26      23   Topic9  0.149   eliot_middlemarch_ch1.txt      eliot
# 27      23  Topic13  0.122   eliot_middlemarch_ch1.txt      eliot
# 28      23   Topic4  0.345   eliot_middlemarch_ch1.txt      eliot
# 29      28  Topic11  0.457         grimms_snowdrop.txt     grimms
# ..     ...      ...    ...                         ...        ...
# 74      16   Topic2  0.623      brown_davinci_ch77.txt      brown
# 75      19   Topic8  0.404       conrad_secret_ch2.txt     conrad
# 76      19  Topic13  0.124       conrad_secret_ch2.txt     conrad
# 77      19  Topic10  0.137       conrad_secret_ch2.txt     conrad
# 78      18   Topic8  0.285       conrad_secret_ch1.txt     conrad
# 79      18  Topic13  0.107       conrad_secret_ch1.txt     conrad
# 80      18   Topic7  0.115       conrad_secret_ch1.txt     conrad
# 81      18  Topic10  0.103       conrad_secret_ch1.txt     conrad
# 82      31   Topic9  0.113  james_fiftyshades_ch18.txt      james
# 83      31  Topic10  0.208  james_fiftyshades_ch18.txt      james
# 84      31  Topic15  0.502  james_fiftyshades_ch18.txt      james
# 85      30  Topic10  0.178   james_fiftyshades_ch1.txt      james
# 86      30  Topic12  0.460   james_fiftyshades_ch1.txt      james
# 87      30  Topic15  0.109   james_fiftyshades_ch1.txt      james
# 88      37  Topic10  0.139     lewis_lionwitch_ch2.txt      lewis
# 89      37  Topic14  0.525     lewis_lionwitch_ch2.txt      lewis
# 90      36   Topic1  0.507    lewis_lionwitch_ch14.txt      lewis
# 91      36  Topic10  0.111    lewis_lionwitch_ch14.txt      lewis
# 92      36  Topic14  0.102    lewis_lionwitch_ch14.txt      lewis
# 93      35   Topic1  0.396    lewis_lionwitch_ch12.txt      lewis
# 94      35  Topic10  0.136    lewis_lionwitch_ch12.txt      lewis
# 95      35  Topic14  0.140    lewis_lionwitch_ch12.txt      lewis
# 96      35  Topic11  0.109    lewis_lionwitch_ch12.txt      lewis
# 97      34  Topic10  0.195     lewis_lionwitch_ch1.txt      lewis
# 98      34  Topic14  0.443     lewis_lionwitch_ch1.txt      lewis
# 99      33  Topic10  0.194  james_fiftyshades_ch23.txt      james
# 100     33  Topic15  0.491  james_fiftyshades_ch23.txt      james
# 101     32  Topic10  0.142   james_fiftyshades_ch2.txt      james
# 102     32  Topic12  0.421   james_fiftyshades_ch2.txt      james
# 103     32  Topic15  0.126   james_fiftyshades_ch2.txt      james
#
# [104 rows x 5 columns]

# %%
df.columns
# Out:
# Index([u'DocID', u'Topic', u'Score', u'File', u'Author'], dtype='object')

# %%
df[df["Topic"]=="Topic11"]
# Out:
#     DocID    Topic  Score                        File     Author
# 0      42  Topic11  0.335  stevenson_treasure_ch1.txt  stevenson
# 4      43  Topic11  0.326  stevenson_treasure_ch2.txt  stevenson
# 29     28  Topic11  0.457         grimms_snowdrop.txt     grimms
# 31     29  Topic11  0.589      grimms_wateroflife.txt     grimms
# 62     10  Topic11  0.471    barrie_peterpan_ch15.txt     barrie
# 71     14  Topic11  0.105       brown_davinci_ch0.txt      brown
# 96     35  Topic11  0.109    lewis_lionwitch_ch12.txt      lewis

# %%
[x for x in itertools.combinations(pairs['1'],2)]
# Out:
# [((43, 0.10099999999999999), (36, 0.50700000000000001)),
#  ((43, 0.10099999999999999), (35, 0.39600000000000002)),
#  ((36, 0.50700000000000001), (35, 0.39600000000000002))]

# %%
# make a list of edges - with a weight for each pair found.
def make_edges_dict(df):
    from collections import defaultdict
    edges = defaultdict(list)
    import itertools
    for num in range(1,16):
        docIDs = df[df["Topic"]=="Topic" + str(num)]['DocID']
        scores = df[df["Topic"]=="Topic" + str(num)]['Score']
        pairs = zip(docIDs,scores)
        combos = [x for x in itertools.combinations(pairs,2)]
        for pair in combos:
            #print pair
            node1 = pair[0][0]
            node2 = pair[1][0]
            weight1 = pair[0][1]
            weight2 = pair[1][1]
            if weight1 and weight2:
                if weight1 != weight2:
                    weight = (1 / abs(pair[0][1] - pair[1][1])) / 10
                else:
                    weight = 100
                if node2 < node1:
                    node1, node2 = node2, node1
                edges[(node1,node2)].append(weight)
    return edges

# %%
edges = make_edges_dict(df)
edges
# Out:
# defaultdict(<type 'list'>, {(20, 25): [4.347826086956518], (30, 41): [0.81300813008130102], (7, 25): [0.42918454935622313, 3.3333333333333335], (35, 41): [0.60606060606060619], (18, 19): [0.84033613445378152, 2.9411764705882377, 5.8823529411764701], (33, 41): [0.93457943925233633], (23, 26): [5.8823529411764657, 0.37313432835820892], (14, 31): [2.9411764705882364], (38, 40): [2.4390243902439068, 2.6315789473684204], (15, 30): [1.3698630136986298], (12, 17): [0.46511627906976749], (2, 27): [0.19880715705765409], (14, 43): [0.45248868778280532], (15, 34): [1.1111111111111109], (4, 5): [5.555555555555534, 1.6393442622950829], (19, 39): [1.2048192771084334], (5, 24): [1.8518518518518523, 0.68965517241379337], (3, 40): [100], (6, 23): [4.3478260869565286, 0.42735042735042728], (21, 37): [3.8461538461538445], (32, 35): [16.666666666666728], (22, 42): [6.25, 8.333333333333325, 4.347826086956518], (33, 34): [99.999999999997129], (36, 41): [0.52631578947368429], (10, 36): [100], (34, 41): [0.94339622641509457], (18, 36): [12.500000000000011], (10, 14): [0.27322404371584696], (8, 18): [0.6024096385542167], (39, 42): [1.1627906976744187], (2, 18): [3.4482758620689644], (15, 43): [0.68965517241379304], (4, 42): [1.1904761904761907], (20, 21): [5.2631578947368531], (23, 40): [3.0303030303030303], (40, 42): [24.999999999999979], (41, 43): [1.9607843137254908], (18, 31): [0.95238095238095233], (8, 25): [0.49019607843137258, 0.82644628099173567, 0.88495575221238931], (10, 19): [3.8461538461538489], (7, 18): [1.2048192771084336], (2, 7): [9.9999999999999911], (21, 30): [1.5384615384615381], (24, 40): [11.111111111111102], (3, 22): [0.68027210884353728], (22, 36): [9.0909090909090953], (5, 20): [0.65789473684210531], (30, 36): [1.4925373134328355], (22, 30): [1.7857142857142851], (18, 22): [49.999999999999957, 5.2631578947368451, 7.1428571428571432], (42, 43): [0.86206896551724144, 11.111111111111102], (23, 31): [2.7777777777777786], (36, 37): [3.5714285714285703, 0.23640661938534277], (14, 26): [5.2631578947368372], (15, 19): [3.1250000000000013], (1, 25): [0.46728971962616822, 1.3333333333333335], (3, 31): [33.333333333333456], (15, 39): [0.86956521739130432], (4, 24): [1.3888888888888877, 1.1904761904761907], (19, 32): [19.999999999999982], (6, 18): [0.40160642570281119], (21, 26): [1.5624999999999996], (28, 43): [0.76335877862595414], (29, 42): [0.39370078740157488], (35, 43): [0.33898305084745756, 0.87719298245614041, 0.46082949308755755], (18, 43): [0.6802721088435375], (14, 29): [0.20661157024793392], (1, 18): [0.78125], (2, 25): [0.44843049327354256, 2.9411764705882337], (3, 4): [0.90090090090090058, 2.4999999999999996], (4, 7): [3.8461538461538423, 2.6315789473684204], (19, 41): [0.6097560975609756], (5, 6): [1.0309278350515467, 1.4925373134328344], (3, 42): [0.80645161290322576], (21, 35): [4.3478260869565206], (8, 40): [19.999999999999982], (32, 37): [33.333333333333613], (22, 40): [6.2499999999999947], (29, 35): [0.20833333333333334], (36, 43): [0.2463054187192118, 0.71942446043165464], (10, 34): [1.1904761904761902], (34, 39): [4.0000000000000009], (8, 14): [3.8461538461538467], (37, 42): [19.999999999999982], (18, 34): [1.0869565217391304], (22, 31): [1.1627906976744184], (8, 20): [0.73529411764705865], (10, 22): [9.0909090909090953], (3, 19): [0.69444444444444442], (4, 20): [1.0989010989010985], (19, 20): [7.6923076923077023], (22, 35): [7.1428571428571361], (20, 23): [6.6666666666666732], (23, 42): [4.5454545454545414], (30, 35): [2.3809523809523805], (14, 17): [0.34722222222222221], (25, 31): [0.77519379844961234], (1, 6): [1.4285714285714284, 0.82644628099173512], (2, 5): [5.5555555555555678], (24, 42): [100], (5, 8): [2.7027027027027044, 6.250000000000016], (3, 24): [2.5641025641025657, 11.111111111111102, 0.80645161290322576], (6, 7): [1.1235955056179772, 0.6024096385542167], (4, 19): [0.96153846153846145], (5, 18): [0.5494505494505495], (6, 25): [0.69444444444444442, 0.51020408163265296], (21, 31): [9.0909090909090828, 1.05 ...

# %%
df_files = df[['DocID','Author','File']].drop_duplicates()

# %%
df_files
# Out:
#      DocID     Author                        File
# 0       42  stevenson  stevenson_treasure_ch1.txt
# 4       43  stevenson  stevenson_treasure_ch2.txt
# 7       24      eliot   eliot_middlemarch_ch2.txt
# 10      25      eliot  eliot_middlemarch_ch48.txt
# 14      26      eliot  eliot_middlemarch_ch73.txt
# 16      27     grimms     grimms_hanselgretel.txt
# 17      20      doyle    doyle_caseofidentity.txt
# 19      21      doyle   doyle_redheadedleague.txt
# 22      22      doyle    doyle_scandalbohemia.txt
# 26      23      eliot   eliot_middlemarch_ch1.txt
# 29      28     grimms         grimms_snowdrop.txt
# 31      29     grimms      grimms_wateroflife.txt
# 32      40      meyer      meyer_twilight_ch2.txt
# 35      41      meyer     meyer_twilight_ch21.txt
# 37       1     austen        austen_pride_ch1.txt
# 39       3     austen       austen_pride_ch40.txt
# 42       2     austen        austen_pride_ch2.txt
# 44       5     austen        austen_sense_ch1.txt
# 46       4     austen       austen_pride_ch50.txt
# 48       7     austen       austen_sense_ch27.txt
# 50       6     austen        austen_sense_ch2.txt
# 52       9     barrie     barrie_peterpan_ch1.txt
# 53       8     austen       austen_sense_ch41.txt
# 56      39      meyer     meyer_twilight_ch15.txt
# 59      38      meyer      meyer_twilight_ch1.txt
# 61      11     barrie     barrie_peterpan_ch2.txt
# 62      10     barrie    barrie_peterpan_ch15.txt
# 65      13      brown      brown_angels_ch2_4.txt
# 67      12      brown        brown_angels_ch1.txt
# 68      15      brown       brown_davinci_ch1.txt
# 70      14      brown       brown_davinci_ch0.txt
# 73      17      brown      brown_davinci_ch92.txt
# 74      16      brown      brown_davinci_ch77.txt
# 75      19     conrad       conrad_secret_ch2.txt
# 78      18     conrad       conrad_secret_ch1.txt
# 82      31      james  james_fiftyshades_ch18.txt
# 85      30      james   james_fiftyshades_ch1.txt
# 88      37      lewis     lewis_lionwitch_ch2.txt
# 90      36      lewis    lewis_lionwitch_ch14.txt
# 93      35      lewis    lewis_lionwitch_ch12.txt
# 97      34      lewis     lewis_lionwitch_ch1.txt
# 99      33      james  james_fiftyshades_ch23.txt
# 101     32      james   james_fiftyshades_ch2.txt

# %%
def write_gexf_from_csv(excelcsv, outputfile, edgelabel = 'allwords'):
    import networkx as nx
    import pandas as pd
    import numpy as np
    
    df = pd.read_csv(excelcsv)
    edges = make_edges_dict(df)
    g = nx.Graph()
    for pair, weight in edges.iteritems():  # if you haven't modified your dict, will be same order
        g.add_edge(pair[0],pair[1], weight=float(np.mean(weight)), score=float(np.mean(weight)), 
                   count=len(weight), median=float(np.median(weight)), label=edgelabel)
    df_files = df[['DocID','Author','File']].drop_duplicates()
    for index, row in df_files.iterrows():
        g.add_node(row['DocID'], author = row['Author'], label = row['File'])
    nx.write_gexf(g, outputfile)
    return g

# %%
g = write_gexf_from_csv('files/for_excel.csv','files/docs_only_gexf.gexf')

# %%
g.size()
# Out:
# 399

# %%
g.degree()
# Out:
# {1: 16,
#  2: 15,
#  3: 21,
#  4: 16,
#  5: 16,
#  6: 16,
#  7: 16,
#  8: 21,
#  9: 2,
#  10: 24,
#  11: 2,
#  12: 5,
#  13: 9,
#  14: 21,
#  15: 24,
#  16: 5,
#  17: 5,
#  18: 34,
#  19: 31,
#  20: 16,
#  21: 27,
#  22: 34,
#  23: 21,
#  24: 21,
#  25: 23,
#  26: 20,
#  27: 6,
#  28: 11,
#  29: 6,
#  30: 19,
#  31: 26,
#  32: 19,
#  33: 19,
#  34: 19,
#  35: 22,
#  36: 19,
#  37: 19,
#  38: 20,
#  39: 27,
#  40: 27,
#  41: 20,
#  42: 36,
#  43: 22}

# %%
g.nodes(data=True)
# Out:
# [(1, {'author': 'austen', 'label': 'austen_pride_ch1.txt'}),
#  (2, {'author': 'austen', 'label': 'austen_pride_ch2.txt'}),
#  (3, {'author': 'austen', 'label': 'austen_pride_ch40.txt'}),
#  (4, {'author': 'austen', 'label': 'austen_pride_ch50.txt'}),
#  (5, {'author': 'austen', 'label': 'austen_sense_ch1.txt'}),
#  (6, {'author': 'austen', 'label': 'austen_sense_ch2.txt'}),
#  (7, {'author': 'austen', 'label': 'austen_sense_ch27.txt'}),
#  (8, {'author': 'austen', 'label': 'austen_sense_ch41.txt'}),
#  (9, {'author': 'barrie', 'label': 'barrie_peterpan_ch1.txt'}),
#  (10, {'author': 'barrie', 'label': 'barrie_peterpan_ch15.txt'}),
#  (11, {'author': 'barrie', 'label': 'barrie_peterpan_ch2.txt'}),
#  (12, {'author': 'brown', 'label': 'brown_angels_ch1.txt'}),
#  (13, {'author': 'brown', 'label': 'brown_angels_ch2_4.txt'}),
#  (14, {'author': 'brown', 'label': 'brown_davinci_ch0.txt'}),
#  (15, {'author': 'brown', 'label': 'brown_davinci_ch1.txt'}),
#  (16, {'author': 'brown', 'label': 'brown_davinci_ch77.txt'}),
#  (17, {'author': 'brown', 'label': 'brown_davinci_ch92.txt'}),
#  (18, {'author': 'conrad', 'label': 'conrad_secret_ch1.txt'}),
#  (19, {'author': 'conrad', 'label': 'conrad_secret_ch2.txt'}),
#  (20, {'author': 'doyle', 'label': 'doyle_caseofidentity.txt'}),
#  (21, {'author': 'doyle', 'label': 'doyle_redheadedleague.txt'}),
#  (22, {'author': 'doyle', 'label': 'doyle_scandalbohemia.txt'}),
#  (23, {'author': 'eliot', 'label': 'eliot_middlemarch_ch1.txt'}),
#  (24, {'author': 'eliot', 'label': 'eliot_middlemarch_ch2.txt'}),
#  (25, {'author': 'eliot', 'label': 'eliot_middlemarch_ch48.txt'}),
#  (26, {'author': 'eliot', 'label': 'eliot_middlemarch_ch73.txt'}),
#  (27, {'author': 'grimms', 'label': 'grimms_hanselgretel.txt'}),
#  (28, {'author': 'grimms', 'label': 'grimms_snowdrop.txt'}),
#  (29, {'author': 'grimms', 'label': 'grimms_wateroflife.txt'}),
#  (30, {'author': 'james', 'label': 'james_fiftyshades_ch1.txt'}),
#  (31, {'author': 'james', 'label': 'james_fiftyshades_ch18.txt'}),
#  (32, {'author': 'james', 'label': 'james_fiftyshades_ch2.txt'}),
#  (33, {'author': 'james', 'label': 'james_fiftyshades_ch23.txt'}),
#  (34, {'author': 'lewis', 'label': 'lewis_lionwitch_ch1.txt'}),
#  (35, {'author': 'lewis', 'label': 'lewis_lionwitch_ch12.txt'}),
#  (36, {'author': 'lewis', 'label': 'lewis_lionwitch_ch14.txt'}),
#  (37, {'author': 'lewis', 'label': 'lewis_lionwitch_ch2.txt'}),
#  (38, {'author': 'meyer', 'label': 'meyer_twilight_ch1.txt'}),
#  (39, {'author': 'meyer', 'label': 'meyer_twilight_ch15.txt'}),
#  (40, {'author': 'meyer', 'label': 'meyer_twilight_ch2.txt'}),
#  (41, {'author': 'meyer', 'label': 'meyer_twilight_ch21.txt'}),
#  (42, {'author': 'stevenson', 'label': 'stevenson_treasure_ch1.txt'}),
#  (43, {'author': 'stevenson', 'label': 'stevenson_treasure_ch2.txt'})]

# %%
g.edges(data=True)
# Out:
# [(1,
#   2,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 11.111111111111102,
#    'score': 11.111111111111102,
#    'weight': 11.111111111111102}),
#  (1,
#   3,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.2727272727272716,
#    'score': 2.2727272727272716,
#    'weight': 2.2727272727272716}),
#  (1,
#   4,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 8.253968253968274,
#    'score': 8.253968253968274,
#    'weight': 8.253968253968274}),
#  (1,
#   5,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.7777777777777803,
#    'score': 2.7777777777777803,
#    'weight': 2.7777777777777803}),
#  (1,
#   6,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.1275088547815817,
#    'score': 1.1275088547815817,
#    'weight': 1.1275088547815817}),
#  (1,
#   7,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.74269005847953,
#    'score': 3.74269005847953,
#    'weight': 3.74269005847953}),
#  (1,
#   8,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 6.315789473684205,
#    'score': 6.315789473684205,
#    'weight': 6.315789473684205}),
#  (1,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0989010989010992,
#    'score': 1.0989010989010992,
#    'weight': 1.0989010989010992}),
#  (1,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.78125,
#    'score': 0.78125,
#    'weight': 0.78125}),
#  (1,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9009009009009009,
#    'score': 0.9009009009009009,
#    'weight': 0.9009009009009009}),
#  (1,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0204081632653061,
#    'score': 1.0204081632653061,
#    'weight': 1.0204081632653061}),
#  (1,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8771929824561404,
#    'score': 0.8771929824561404,
#    'weight': 0.8771929824561404}),
#  (1,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.5063076633402364,
#    'score': 1.5063076633402364,
#    'weight': 1.5063076633402364}),
#  (1,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.4013024013023996,
#    'score': 2.4013024013023996,
#    'weight': 2.4013024013023996}),
#  (1,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.9003115264797509,
#    'score': 0.9003115264797509,
#    'weight': 0.9003115264797509}),
#  (1,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6451612903225805,
#    'score': 0.6451612903225805,
#    'weight': 0.6451612903225805}),
#  (2,
#   3,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3333333333333333,
#    'score': 1.3333333333333333,
#    'weight': 1.3333333333333333}),
#  (2,
#   4,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7777777777777755,
#    'score': 2.7777777777777755,
#    'weight': 2.7777777777777755}),
#  (2,
#   5,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.555555555555568,
#    'score': 5.555555555555568,
#    'weight': 5.555555555555568}),
#  (2,
#   6,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2658227848101264,
#    'score': 1.2658227848101264,
#    'weight': 1.2658227848101264}),
#  (2,
#   7,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 9.999999999999991,
#    'score': 9.999999999999991,
#    'weight': 9.999999999999991}),
#  (2,
#   8,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736837,
#    'score': 5.263157894736837,
#    'weight': 5.263157894736837}),
#  (2,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.666666666666662,
#    'score': 6.666666666666662,
#    'weight': 6.666666666666662}),
#  (2,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.4482758620689644,
#    'score': 3.4482758620689644,
#    'weight': 3.4482758620689644}),
#  (2,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.2258064516129017,
#    'score': 3.2258064516129017,
#    'weight': 3.2258064516129017}),
#  (2,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.785714285714284,
#    'score': 1.785714285714284,
#    'weight': 1.785714285714284}),
#  (2,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7777777777777755,
#    'score': 2.7777777777777755,
#    'weight': 2.7777777777777755}),
#  (2,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.6948034819308881,
#    'score': 1.6948034819308881,
#    'weight': 1.6948034819308881}),
#  (2,
#   27,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.1988071570576541,
#    'score': 0.1988071570576541,
#    'weight': 0.1988071570576541}),
#  (2,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0101010101010104,
#    'score': 1.0101010101010104,
#    'weight': 1.0101010101010104}),
#  (3,
#   4,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.70045045045045,
#    'score': 1.70045045045045,
#    'weight': 1.70045045045045}),
#  (3,
#   5,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.918586789554536,
#    'score': 2.918586789554536,
#    'weight': 2.918586789554536}),
#  (3,
#   6,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 13.068181818181808,
#    'score': 13.068181818181808,
#    'weight': 13.068181818181808}),
#  (3,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 10.000000000000005,
#    'score': 10.000000000000005,
#    'weight': 10.000000000000005}),
#  (3,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (3,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8064516129032258,
#    'score': 0.8064516129032258,
#    'weight': 0.8064516129032258}),
#  (3,
#   7,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.2292609351432877,
#    'score': 1.2292609351432877,
#    'weight': 1.2292609351432877}),
#  (3,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.225806451612903,
#    'score': 3.225806451612903,
#    'weight': 3.225806451612903}),
#  (3,
#   8,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 19.999999999999982,
#    'score': 13.928571428571416,
#    'weight': 13.928571428571416}),
#  (3,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6211180124223601,
#    'score': 0.6211180124223601,
#    'weight': 0.6211180124223601}),
#  (3,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6944444444444444,
#    'score': 0.6944444444444444,
#    'weight': 0.6944444444444444}),
#  (3,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.763358778625954,
#    'score': 0.763358778625954,
#    'weight': 0.763358778625954}),
#  (3,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.142857142857143,
#    'score': 7.142857142857143,
#    'weight': 7.142857142857143}),
#  (3,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6802721088435373,
#    'score': 0.6802721088435373,
#    'weight': 0.6802721088435373}),
#  (3,
#   23,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 3.0303030303030303,
#    'score': 2.9927974772963997,
#    'weight': 2.9927974772963997}),
#  (3,
#   24,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.5641025641025657,
#    'score': 4.827221762705631,
#    'weight': 4.827221762705631}),
#  (3,
#   25,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 0.7936507936507937,
#    'score': 0.7984174650841318,
#    'weight': 0.7984174650841318}),
#  (3,
#   26,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.40983606557377,
#    'score': 1.40983606557377,
#    'weight': 1.40983606557377}),
#  (3,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 33.33333333333346,
#    'score': 33.33333333333346,
#    'weight': 33.33333333333346}),
#  (4,
#   5,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.5974499089253085,
#    'score': 3.5974499089253085,
#    'weight': 3.5974499089253085}),
#  (4,
#   6,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8254076086956519,
#    'score': 0.8254076086956519,
#    'weight': 0.8254076086956519}),
#  (4,
#   7,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.2388663967611313,
#    'score': 3.2388663967611313,
#    'weight': 3.2388663967611313}),
#  (4,
#   8,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.020202020202019,
#    'score': 2.020202020202019,
#    'weight': 2.020202020202019}),
#  (4,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761907,
#    'score': 1.1904761904761907,
#    'weight': 1.1904761904761907}),
#  (4,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8264462809917354,
#    'score': 0.8264462809917354,
#    'weight': 0.8264462809917354}),
#  (4,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9615384615384615,
#    'score': 0.9615384615384615,
#    'weight': 0.9615384615384615}),
#  (4,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0989010989010985,
#    'score': 1.0989010989010985,
#    'weight': 1.0989010989010985}),
#  (4,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9345794392523363,
#    'score': 0.9345794392523363,
#    'weight': 0.9345794392523363}),
#  (4,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.0151763740771118,
#    'score': 1.0151763740771118,
#    'weight': 1.0151763740771118}),
#  (4,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.289682539682539,
#    'score': 1.289682539682539,
#    'weight': 1.289682539682539}),
#  (4,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.9283443106972518,
#    'score': 0.9283443106972518,
#    'weight': 0.9283443106972518}),
#  (4,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6172839506172839,
#    'score': 0.6172839506172839,
#    'weight': 0.6172839506172839}),
#  (5,
#   6,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.2617325742421905,
#    'score': 1.2617325742421905,
#    'weight': 1.2617325742421905}),
#  (5,
#   7,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 6.7550505050505425,
#    'score': 6.7550505050505425,
#    'weight': 6.7550505050505425}),
#  (5,
#   8,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 4.47635135135136,
#    'score': 4.47635135135136,
#    'weight': 4.47635135135136}),
#  (5,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6896551724137934,
#    'score': 0.6896551724137934,
#    'weight': 0.6896551724137934}),
#  (5,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5494505494505495,
#    'score': 0.5494505494505495,
#    'weight': 0.5494505494505495}),
#  (5,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6060606060606062,
#    'score': 0.6060606060606062,
#    'weight': 0.6060606060606062}),
#  (5,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6578947368421053,
#    'score': 0.6578947368421053,
#    'weight': 0.6578947368421053}),
#  (5,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5952380952380953,
#    'score': 0.5952380952380953,
#    'weight': 0.5952380952380953}),
#  (5,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.9750768732804661,
#    'score': 0.9750768732804661,
#    'weight': 0.9750768732804661}),
#  (5,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.2707535121328228,
#    'score': 1.2707535121328228,
#    'weight': 1.2707535121328228}),
#  (5,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.5950657788928561,
#    'score': 0.5950657788928561,
#    'weight': 0.5950657788928561}),
#  (5,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9900990099009898,
#    'score': 0.9900990099009898,
#    'weight': 0.9900990099009898}),
#  (6,
#   7,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.863002572086097,
#    'score': 0.863002572086097,
#    'weight': 0.863002572086097}),
#  (6,
#   8,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.43574297188755,
#    'score': 1.43574297188755,
#    'weight': 1.43574297188755}),
#  (6,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4716981132075471,
#    'score': 0.4716981132075471,
#    'weight': 0.4716981132075471}),
#  (6,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4016064257028112,
#    'score': 0.4016064257028112,
#    'weight': 0.4016064257028112}),
#  (6,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.43103448275862066,
#    'score': 0.43103448275862066,
#    'weight': 0.43103448275862066}),
#  (6,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4566210045662099,
#    'score': 0.4566210045662099,
#    'weight': 0.4566210045662099}),
#  (6,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4255319148936169,
#    'score': 0.4255319148936169,
#    'weight': 0.4255319148936169}),
#  (6,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.387588257153478,
#    'score': 2.387588257153478,
#    'weight': 2.387588257153478}),
#  (6,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.3986397542781928,
#    'score': 1.3986397542781928,
#    'weight': 1.3986397542781928}),
#  (6,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.6023242630385487,
#    'score': 0.6023242630385487,
#    'weight': 0.6023242630385487}),
#  (6,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.9411764705882377,
#    'score': 2.9411764705882377,
#    'weight': 2.9411764705882377}),
#  (7,
#   8,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.3265475695886977,
#    'score': 2.3265475695886977,
#    'weight': 2.3265475695886977}),
#  (7,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.1739130434782616,
#    'score': 2.1739130434782616,
#    'weight': 2.1739130434782616}),
#  (7,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2048192771084336,
#    'score': 1.2048192771084336,
#    'weight': 1.2048192771084336}),
#  (7,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.5151515151515151,
#    'score': 1.5151515151515151,
#    'weight': 1.5151515151515151}),
#  (7,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.886792452830188,
#    'score': 1.886792452830188,
#    'weight': 1.886792452830188}),
#  (7,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4492753623188404,
#    'score': 1.4492753623188404,
#    'weight': 1.4492753623188404}),
#  (7,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.4928698752228158,
#    'score': 1.4928698752228158,
#    'weight': 1.4928698752228158}),
#  (7,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.1739130434782603,
#    'score': 2.1739130434782603,
#    'weight': 2.1739130434782603}),
#  (7,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.8812589413447782,
#    'score': 1.8812589413447782,
#    'weight': 1.8812589413447782}),
#  (7,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5,
#    'score': 0.5,
#    'weight': 0.5}),
#  (8,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.666666666666667,
#    'score': 6.666666666666667,
#    'weight': 6.666666666666667}),
#  (8,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (8,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7751937984496123,
#    'score': 0.7751937984496123,
#    'weight': 0.7751937984496123}),
#  (8,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.8461538461538467,
#    'score': 3.8461538461538467,
#    'weight': 3.8461538461538467}),
#  (8,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6024096385542167,
#    'score': 0.6024096385542167,
#    'weight': 0.6024096385542167}),
#  (8,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6711409395973154,
#    'score': 0.6711409395973154,
#    'weight': 0.6711409395973154}),
#  (8,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7352941176470587,
#    'score': 0.7352941176470587,
#    'weight': 0.7352941176470587}),
#  (8,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736841,
#    'score': 5.263157894736841,
#    'weight': 5.263157894736841}),
#  (8,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6578947368421051,
#    'score': 0.6578947368421051,
#    'weight': 0.6578947368421051}),
#  (8,
#   23,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.7027027027027004,
#    'score': 2.3121276432534703,
#    'weight': 2.3121276432534703}),
#  (8,
#   24,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 5.882352941176466,
#    'score': 10.552515579875353,
#    'weight': 10.552515579875353}),
#  (8,
#   25,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 0.8264462809917357,
#    'score': 0.7338660372118325,
#    'weight': 0.7338660372118325}),
#  (8,
#   26,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.5384615384615383,
#    'score': 1.5384615384615383,
#    'weight': 1.5384615384615383}),
#  (8,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.50000000000001,
#    'score': 12.50000000000001,
#    'weight': 12.50000000000001}),
#  (9,
#   10,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.2597402597402597,
#    'score': 0.2597402597402597,
#    'weight': 0.2597402597402597}),
#  (9,
#   11,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2500000000000007,
#    'score': 1.2500000000000007,
#    'weight': 1.2500000000000007}),
#  (10,
#   11,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.21505376344086025,
#    'score': 0.21505376344086025,
#    'weight': 0.21505376344086025}),
#  (10,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.27322404371584696,
#    'score': 0.27322404371584696,
#    'weight': 0.27322404371584696}),
#  (10,
#   15,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (10,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.50000000000001,
#    'score': 12.50000000000001,
#    'weight': 12.50000000000001}),
#  (10,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.846153846153849,
#    'score': 3.846153846153849,
#    'weight': 3.846153846153849}),
#  (10,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (10,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 9.090909090909095,
#    'score': 9.090909090909095,
#    'weight': 9.090909090909095}),
#  (10,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.142857142857136,
#    'score': 7.142857142857136,
#    'weight': 7.142857142857136}),
#  (10,
#   29,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8474576271186445,
#    'score': 0.8474576271186445,
#    'weight': 0.8474576271186445}),
#  (10,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4925373134328355,
#    'score': 1.4925373134328355,
#    'weight': 1.4925373134328355}),
#  (10,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0309278350515463,
#    'score': 1.0309278350515463,
#    'weight': 1.0309278350515463}),
#  (10,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.225806451612905,
#    'score': 3.225806451612905,
#    'weight': 3.225806451612905}),
#  (10,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.204819277108434,
#    'score': 1.204819277108434,
#    'weight': 1.204819277108434}),
#  (10,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761902,
#    'score': 1.1904761904761902,
#    'weight': 1.1904761904761902}),
#  (10,
#   35,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.138121546961325,
#    'score': 2.138121546961325,
#    'weight': 2.138121546961325}),
#  (10,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (10,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.5714285714285703,
#    'score': 3.5714285714285703,
#    'weight': 3.5714285714285703}),
#  (10,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.538461538461538,
#    'score': 1.538461538461538,
#    'weight': 1.538461538461538}),
#  (10,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9174311926605505,
#    'score': 0.9174311926605505,
#    'weight': 0.9174311926605505}),
#  (10,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.7037037037037024,
#    'score': 3.7037037037037024,
#    'weight': 3.7037037037037024}),
#  (10,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5263157894736843,
#    'score': 0.5263157894736843,
#    'weight': 0.5263157894736843}),
#  (10,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.5415601023017897,
#    'score': 2.5415601023017897,
#    'weight': 2.5415601023017897}),
#  (10,
#   43,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.7045398164227239,
#    'score': 0.7045398164227239,
#    'weight': 0.7045398164227239}),
#  (12,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4219409282700422,
#    'score': 0.4219409282700422,
#    'weight': 0.4219409282700422}),
#  (12,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4651162790697675,
#    'score': 0.4651162790697675,
#    'weight': 0.4651162790697675}),
#  (12,
#   13,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.857142857142859,
#    'score': 2.857142857142859,
#    'weight': 2.857142857142859}),
#  (12,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3698630136986298,
#    'score': 1.3698630136986298,
#    'weight': 1.3698630136986298}),
#  (12,
#   15,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.0408163265306127,
#    'score': 2.0408163265306127,
#    'weight': 2.0408163265306127}),
#  (13,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.37174721189591076,
#    'score': 0.37174721189591076,
#    'weight': 0.37174721189591076}),
#  (13,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7692307692307692,
#    'score': 0.7692307692307692,
#    'weight': 0.7692307692307692}),
#  (13,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.32258064516129037,
#    'score': 0.32258064516129037,
#    'weight': 0.32258064516129037}),
#  (13,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5917159763313611,
#    'score': 0.5917159763313611,
#    'weight': 0.5917159763313611}),
#  (13,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.6315789473684186,
#    'score': 2.6315789473684186,
#    'weight': 2.6315789473684186}),
#  (13,
#   15,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761911,
#    'score': 1.1904761904761911,
#    'weight': 1.1904761904761911}),
#  (13,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3676470588235295,
#    'score': 0.3676470588235295,
#    'weight': 0.3676470588235295}),
#  (13,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4000000000000001,
#    'score': 0.4000000000000001,
#    'weight': 0.4000000000000001}),
#  (14,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (14,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.439024390243903,
#    'score': 2.439024390243903,
#    'weight': 2.439024390243903}),
#  (14,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4524886877828053,
#    'score': 0.4524886877828053,
#    'weight': 0.4524886877828053}),
#  (14,
#   15,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8196721311475409,
#    'score': 0.8196721311475409,
#    'weight': 0.8196721311475409}),
#  (14,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.32258064516129037,
#    'score': 0.32258064516129037,
#    'weight': 0.32258064516129037}),
#  (14,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3472222222222222,
#    'score': 0.3472222222222222,
#    'weight': 0.3472222222222222}),
#  (14,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.43478260869565205,
#    'score': 0.43478260869565205,
#    'weight': 0.43478260869565205}),
#  (14,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.225806451612903,
#    'score': 3.225806451612903,
#    'weight': 3.225806451612903}),
#  (14,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.2222222222222223,
#    'score': 2.2222222222222223,
#    'weight': 2.2222222222222223}),
#  (14,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (14,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.545454545454548,
#    'score': 4.545454545454548,
#    'weight': 4.545454545454548}),
#  (14,
#   25,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0526315789473686,
#    'score': 1.0526315789473686,
#    'weight': 1.0526315789473686}),
#  (14,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736837,
#    'score': 5.263157894736837,
#    'weight': 5.263157894736837}),
#  (14,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.28409090909090906,
#    'score': 0.28409090909090906,
#    'weight': 0.28409090909090906}),
#  (14,
#   29,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.20661157024793392,
#    'score': 0.20661157024793392,
#    'weight': 0.20661157024793392}),
#  (14,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.9411764705882364,
#    'score': 2.9411764705882364,
#    'weight': 2.9411764705882364}),
#  (15,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5319148936170213,
#    'score': 0.5319148936170213,
#    'weight': 0.5319148936170213}),
#  (15,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6024096385542169,
#    'score': 0.6024096385542169,
#    'weight': 0.6024096385542169}),
#  (15,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 50.0000000000003,
#    'score': 50.0000000000003,
#    'weight': 50.0000000000003}),
#  (15,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.1250000000000013,
#    'score': 3.1250000000000013,
#    'weight': 3.1250000000000013}),
#  (15,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.49999999999999,
#    'score': 12.49999999999999,
#    'weight': 12.49999999999999}),
#  (15,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.88235294117647,
#    'score': 5.88235294117647,
#    'weight': 5.88235294117647}),
#  (15,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3698630136986298,
#    'score': 1.3698630136986298,
#    'weight': 1.3698630136986298}),
#  (15,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9708737864077668,
#    'score': 0.9708737864077668,
#    'weight': 0.9708737864077668}),
#  (15,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7027027027027035,
#    'score': 2.7027027027027035,
#    'weight': 2.7027027027027035}),
#  (15,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1235955056179778,
#    'score': 1.1235955056179778,
#    'weight': 1.1235955056179778}),
#  (15,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.111111111111111,
#    'score': 1.111111111111111,
#    'weight': 1.111111111111111}),
#  (15,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.2258064516129017,
#    'score': 3.2258064516129017,
#    'weight': 3.2258064516129017}),
#  (15,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (15,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.9411764705882337,
#    'score': 2.9411764705882337,
#    'weight': 2.9411764705882337}),
#  (15,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4084507042253516,
#    'score': 1.4084507042253516,
#    'weight': 1.4084507042253516}),
#  (15,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8695652173913043,
#    'score': 0.8695652173913043,
#    'weight': 0.8695652173913043}),
#  (15,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.030303030303029,
#    'score': 3.030303030303029,
#    'weight': 3.030303030303029}),
#  (15,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5102040816326531,
#    'score': 0.5102040816326531,
#    'weight': 0.5102040816326531}),
#  (15,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.4482758620689644,
#    'score': 3.4482758620689644,
#    'weight': 3.4482758620689644}),
#  (15,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.689655172413793,
#    'score': 0.689655172413793,
#    'weight': 0.689655172413793}),
#  (16,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.545454545454541,
#    'score': 4.545454545454541,
#    'weight': 4.545454545454541}),
#  (18,
#   19,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.9411764705882377,
#    'score': 3.221288515406163,
#    'weight': 3.221288515406163}),
#  (18,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.333333333333335,
#    'score': 3.333333333333335,
#    'weight': 3.333333333333335}),
#  (18,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 10.000000000000005,
#    'score': 10.000000000000005,
#    'weight': 10.000000000000005}),
#  (18,
#   22,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 7.142857142857143,
#    'score': 20.802005012531314,
#    'weight': 20.802005012531314}),
#  (18,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.666666666666667,
#    'score': 6.666666666666667,
#    'weight': 6.666666666666667}),
#  (18,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7027027027027013,
#    'score': 2.7027027027027013,
#    'weight': 2.7027027027027013}),
#  (18,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 10.943396226415086,
#    'score': 10.943396226415086,
#    'weight': 10.943396226415086}),
#  (18,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3533568904593639,
#    'score': 0.3533568904593639,
#    'weight': 0.3533568904593639}),
#  (18,
#   27,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.18796992481203006,
#    'score': 0.18796992481203006,
#    'weight': 0.18796992481203006}),
#  (18,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.78125,
#    'score': 0.78125,
#    'weight': 0.78125}),
#  (18,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3333333333333333,
#    'score': 1.3333333333333333,
#    'weight': 1.3333333333333333}),
#  (18,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9523809523809523,
#    'score': 0.9523809523809523,
#    'weight': 0.9523809523809523}),
#  (18,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.5641025641025657,
#    'score': 2.5641025641025657,
#    'weight': 2.5641025641025657}),
#  (18,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0989010989010992,
#    'score': 1.0989010989010992,
#    'weight': 1.0989010989010992}),
#  (18,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0869565217391304,
#    'score': 1.0869565217391304,
#    'weight': 1.0869565217391304}),
#  (18,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.0303030303030303,
#    'score': 3.0303030303030303,
#    'weight': 3.0303030303030303}),
#  (18,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.50000000000001,
#    'score': 12.50000000000001,
#    'weight': 12.50000000000001}),
#  (18,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7777777777777777,
#    'score': 2.7777777777777777,
#    'weight': 2.7777777777777777}),
#  (18,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3698630136986298,
#    'score': 1.3698630136986298,
#    'weight': 1.3698630136986298}),
#  (18,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8547008547008547,
#    'score': 0.8547008547008547,
#    'weight': 0.8547008547008547}),
#  (18,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.8571428571428568,
#    'score': 2.8571428571428568,
#    'weight': 2.8571428571428568}),
#  (18,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5050505050505051,
#    'score': 0.5050505050505051,
#    'weight': 0.5050505050505051}),
#  (18,
#   42,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 3.225806451612903,
#    'score': 4.357122099057583,
#    'weight': 4.357122099057583}),
#  (18,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6802721088435375,
#    'score': 0.6802721088435375,
#    'weight': 0.6802721088435375}),
#  (19,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.692307692307702,
#    'score': 7.692307692307702,
#    'weight': 7.692307692307702}),
#  (19,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.16666666666667,
#    'score': 4.16666666666667,
#    'weight': 4.16666666666667}),
#  (19,
#   22,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 19.999999999999986,
#    'score': 19.999999999999986,
#    'weight': 19.999999999999986}),
#  (19,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (19,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.999999999999996,
#    'score': 4.999999999999996,
#    'weight': 4.999999999999996}),
#  (19,
#   25,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7777777777777777,
#    'score': 2.7777777777777777,
#    'weight': 2.7777777777777777}),
#  (19,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.37593984962406013,
#    'score': 0.37593984962406013,
#    'weight': 0.37593984962406013}),
#  (19,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.4390243902439,
#    'score': 2.4390243902439,
#    'weight': 2.4390243902439}),
#  (19,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4084507042253516,
#    'score': 1.4084507042253516,
#    'weight': 1.4084507042253516}),
#  (19,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (19,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7543859649122808,
#    'score': 1.7543859649122808,
#    'weight': 1.7543859649122808}),
#  (19,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7241379310344822,
#    'score': 1.7241379310344822,
#    'weight': 1.7241379310344822}),
#  (19,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 100.00000000000269,
#    'score': 100.00000000000269,
#    'weight': 100.00000000000269}),
#  (19,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.846153846153849,
#    'score': 3.846153846153849,
#    'weight': 3.846153846153849}),
#  (19,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999926,
#    'score': 49.99999999999926,
#    'weight': 49.99999999999926}),
#  (19,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.5641025641025617,
#    'score': 2.5641025641025617,
#    'weight': 2.5641025641025617}),
#  (19,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2048192771084334,
#    'score': 1.2048192771084334,
#    'weight': 1.2048192771084334}),
#  (19,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 99.99999999999713,
#    'score': 99.99999999999713,
#    'weight': 99.99999999999713}),
#  (19,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6097560975609756,
#    'score': 0.6097560975609756,
#    'weight': 0.6097560975609756}),
#  (19,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 19.166666666666803,
#    'score': 19.166666666666803,
#    'weight': 19.166666666666803}),
#  (19,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8849557522123893,
#    'score': 0.8849557522123893,
#    'weight': 0.8849557522123893}),
#  (20,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 14.285714285714215,
#    'score': 14.285714285714215,
#    'weight': 14.285714285714215}),
#  (20,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736853,
#    'score': 5.263157894736853,
#    'weight': 5.263157894736853}),
#  (20,
#   22,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.9724576271186467,
#    'score': 3.9724576271186467,
#    'weight': 3.9724576271186467}),
#  (20,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.666666666666673,
#    'score': 6.666666666666673,
#    'weight': 6.666666666666673}),
#  (20,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 14.285714285714215,
#    'score': 14.285714285714215,
#    'weight': 14.285714285714215}),
#  (20,
#   25,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.347826086956518,
#    'score': 4.347826086956518,
#    'weight': 4.347826086956518}),
#  (20,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3952569169960474,
#    'score': 0.3952569169960474,
#    'weight': 0.3952569169960474}),
#  (21,
#   22,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 6.1965811965812,
#    'score': 6.1965811965812,
#    'weight': 6.1965811965812}),
#  (21,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.127659574468085,
#    'score': 2.127659574468085,
#    'weight': 2.127659574468085}),
#  (21,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.347826086956521,
#    'score': 4.347826086956521,
#    'weight': 4.347826086956521}),
#  (21,
#   25,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7142857142857142,
#    'score': 0.7142857142857142,
#    'weight': 0.7142857142857142}),
#  (21,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.5624999999999996,
#    'score': 1.5624999999999996,
#    'weight': 1.5624999999999996}),
#  (21,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.538461538461538,
#    'score': 1.538461538461538,
#    'weight': 1.538461538461538}),
#  (21,
#   31,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 5.0717703349282255,
#    'score': 5.0717703349282255,
#    'weight': 5.0717703349282255}),
#  (21,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.448275862068967,
#    'score': 3.448275862068967,
#    'weight': 3.448275862068967}),
#  (21,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2345679012345683,
#    'score': 1.2345679012345683,
#    'weight': 1.2345679012345683}),
#  (21,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2195121951219512,
#    'score': 1.2195121951219512,
#    'weight': 1.2195121951219512}),
#  (21,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.347826086956521,
#    'score': 4.347826086956521,
#    'weight': 4.347826086956521}),
#  (21,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (21,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.8461538461538445,
#    'score': 3.8461538461538445,
#    'weight': 3.8461538461538445}),
#  (21,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.587301587301587,
#    'score': 1.587301587301587,
#    'weight': 1.587301587301587}),
#  (21,
#   39,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 12.967289719626157,
#    'score': 12.967289719626157,
#    'weight': 12.967289719626157}),
#  (21,
#   40,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 5.571428571428571,
#    'score': 5.571428571428571,
#    'weight': 5.571428571428571}),
#  (21,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5319148936170213,
#    'score': 0.5319148936170213,
#    'weight': 0.5319148936170213}),
#  (21,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.761904761904761,
#    'score': 4.761904761904761,
#    'weight': 4.761904761904761}),
#  (21,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.72992700729927,
#    'score': 0.72992700729927,
#    'weight': 0.72992700729927}),
#  (22,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (22,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.347826086956518,
#    'score': 4.347826086956518,
#    'weight': 4.347826086956518}),
#  (22,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 17.94871794871793,
#    'score': 17.94871794871793,
#    'weight': 17.94871794871793}),
#  (22,
#   26,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.37174721189591076,
#    'score': 0.37174721189591076,
#    'weight': 0.37174721189591076}),
#  (22,
#   27,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.18726591760299624,
#    'score': 0.18726591760299624,
#    'weight': 0.18726591760299624}),
#  (22,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7692307692307692,
#    'score': 0.7692307692307692,
#    'weight': 0.7692307692307692}),
#  (22,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7857142857142851,
#    'score': 1.7857142857142851,
#    'weight': 1.7857142857142851}),
#  (22,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1627906976744184,
#    'score': 1.1627906976744184,
#    'weight': 1.1627906976744184}),
#  (22,
#   32,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.000000000000003,
#    'score': 5.000000000000003,
#    'weight': 5.000000000000003}),
#  (22,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3888888888888893,
#    'score': 1.3888888888888893,
#    'weight': 1.3888888888888893}),
#  (22,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3698630136986298,
#    'score': 1.3698630136986298,
#    'weight': 1.3698630136986298}),
#  (22,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.142857142857136,
#    'score': 7.142857142857136,
#    'weight': 7.142857142857136}),
#  (22,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 9.090909090909095,
#    'score': 9.090909090909095,
#    'weight': 9.090909090909095}),
#  (22,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.882352941176466,
#    'score': 5.882352941176466,
#    'weight': 5.882352941176466}),
#  (22,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.8518518518518512,
#    'score': 1.8518518518518512,
#    'weight': 1.8518518518518512}),
#  (22,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0204081632653061,
#    'score': 1.0204081632653061,
#    'weight': 1.0204081632653061}),
#  (22,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.249999999999995,
#    'score': 6.249999999999995,
#    'weight': 6.249999999999995}),
#  (22,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5586592178770949,
#    'score': 0.5586592178770949,
#    'weight': 0.5586592178770949}),
#  (22,
#   42,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 6.25,
#    'score': 6.310386473429948,
#    'weight': 6.310386473429948}),
#  (22,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.78125,
#    'score': 0.78125,
#    'weight': 0.78125}),
#  (23,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.0303030303030303,
#    'score': 3.0303030303030303,
#    'weight': 3.0303030303030303}),
#  (23,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.545454545454541,
#    'score': 4.545454545454541,
#    'weight': 4.545454545454541}),
#  (23,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3255813953488373,
#    'score': 2.3255813953488373,
#    'weight': 2.3255813953488373}),
#  (23,
#   24,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 4.545454545454541,
#    'score': 4.570707070707068,
#    'weight': 4.570707070707068}),
#  (23,
#   25,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 1.075268817204301,
#    'score': 1.4352167199274344,
#    'weight': 1.4352167199274344}),
#  (23,
#   26,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.127743634767337,
#    'score': 3.127743634767337,
#    'weight': 3.127743634767337}),
#  (23,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7777777777777786,
#    'score': 2.7777777777777786,
#    'weight': 2.7777777777777786}),
#  (24,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736841,
#    'score': 5.263157894736841,
#    'weight': 5.263157894736841}),
#  (24,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 11.111111111111102,
#    'score': 11.111111111111102,
#    'weight': 11.111111111111102}),
#  (24,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (24,
#   25,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 0.8547008547008547,
#    'score': 2.54648673766321,
#    'weight': 2.54648673766321}),
#  (24,
#   26,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.4227642276422763,
#    'score': 1.4227642276422763,
#    'weight': 1.4227642276422763}),
#  (24,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 8.333333333333336,
#    'score': 8.333333333333336,
#    'weight': 8.333333333333336}),
#  (25,
#   26,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8752860411899315,
#    'score': 0.8752860411899315,
#    'weight': 0.8752860411899315}),
#  (25,
#   27,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.18621973929236496,
#    'score': 0.18621973929236496,
#    'weight': 0.18621973929236496}),
#  (25,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7518796992481203,
#    'score': 0.7518796992481203,
#    'weight': 0.7518796992481203}),
#  (25,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7751937984496123,
#    'score': 0.7751937984496123,
#    'weight': 0.7751937984496123}),
#  (25,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7352941176470588,
#    'score': 0.7352941176470588,
#    'weight': 0.7352941176470588}),
#  (25,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7936507936507937,
#    'score': 0.7936507936507937,
#    'weight': 0.7936507936507937}),
#  (25,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 5.756578947368423,
#    'score': 5.756578947368423,
#    'weight': 5.756578947368423}),
#  (26,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.6666666666666665,
#    'score': 1.6666666666666665,
#    'weight': 1.6666666666666665}),
#  (26,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.40650406504065045,
#    'score': 0.40650406504065045,
#    'weight': 0.40650406504065045}),
#  (26,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.9999999999999993,
#    'score': 1.9999999999999993,
#    'weight': 1.9999999999999993}),
#  (26,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.8867924528301885,
#    'score': 1.8867924528301885,
#    'weight': 1.8867924528301885}),
#  (27,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.19305019305019305,
#    'score': 0.19305019305019305,
#    'weight': 0.19305019305019305}),
#  (27,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.24752475247524752,
#    'score': 0.24752475247524752,
#    'weight': 0.24752475247524752}),
#  (28,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.28735632183908044,
#    'score': 0.28735632183908044,
#    'weight': 0.28735632183908044}),
#  (28,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8484325568018407,
#    'score': 0.8484325568018407,
#    'weight': 0.8484325568018407}),
#  (28,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7633587786259541,
#    'score': 0.7633587786259541,
#    'weight': 0.7633587786259541}),
#  (28,
#   29,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7575757575757579,
#    'score': 0.7575757575757579,
#    'weight': 0.7575757575757579}),
#  (29,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.20833333333333334,
#    'score': 0.20833333333333334,
#    'weight': 0.20833333333333334}),
#  (29,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3937007874015749,
#    'score': 0.3937007874015749,
#    'weight': 0.3937007874015749}),
#  (29,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3802281368821293,
#    'score': 0.3802281368821293,
#    'weight': 0.3802281368821293}),
#  (30,
#   32,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.7777777777777755,
#    'score': 3.7414110943522707,
#    'weight': 3.7414110943522707}),
#  (30,
#   33,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.255890052356029,
#    'score': 3.255890052356029,
#    'weight': 3.255890052356029}),
#  (30,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.8823529411764754,
#    'score': 5.8823529411764754,
#    'weight': 5.8823529411764754}),
#  (30,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523805,
#    'score': 2.3809523809523805,
#    'weight': 2.3809523809523805}),
#  (30,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4925373134328355,
#    'score': 1.4925373134328355,
#    'weight': 1.4925373134328355}),
#  (30,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.5641025641025634,
#    'score': 2.5641025641025634,
#    'weight': 2.5641025641025634}),
#  (30,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (30,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523823,
#    'score': 2.3809523809523823,
#    'weight': 2.3809523809523823}),
#  (30,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.4999999999999996,
#    'score': 2.4999999999999996,
#    'weight': 2.4999999999999996}),
#  (30,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.813008130081301,
#    'score': 0.813008130081301,
#    'weight': 0.813008130081301}),
#  (30,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.2727272727272725,
#    'score': 2.2727272727272725,
#    'weight': 2.2727272727272725}),
#  (30,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3888888888888893,
#    'score': 1.3888888888888893,
#    'weight': 1.3888888888888893}),
#  (30,
#   31,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.7938931297709924,
#    'score': 1.7938931297709924,
#    'weight': 1.7938931297709924}),
#  (31,
#   32,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8905544809800126,
#    'score': 0.8905544809800126,
#    'weight': 0.8905544809800126}),
#  (31,
#   33,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 8.116883116883102,
#    'score': 8.116883116883102,
#    'weight': 8.116883116883102}),
#  (31,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.6923076923076845,
#    'score': 7.6923076923076845,
#    'weight': 7.6923076923076845}),
#  (31,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3888888888888888,
#    'score': 1.3888888888888888,
#    'weight': 1.3888888888888888}),
#  (31,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0309278350515463,
#    'score': 1.0309278350515463,
#    'weight': 1.0309278350515463}),
#  (31,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4492753623188404,
#    'score': 1.4492753623188404,
#    'weight': 1.4492753623188404}),
#  (31,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.125,
#    'score': 3.125,
#    'weight': 3.125}),
#  (31,
#   39,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 11.30952380952381,
#    'score': 11.30952380952381,
#    'weight': 11.30952380952381}),
#  (31,
#   40,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 17.380952380952444,
#    'score': 17.380952380952444,
#    'weight': 17.380952380952444}),
#  (31,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0752688172043015,
#    'score': 1.0752688172043015,
#    'weight': 1.0752688172043015}),
#  (31,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3513513513513513,
#    'score': 1.3513513513513513,
#    'weight': 1.3513513513513513}),
#  (31,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523823,
#    'score': 2.3809523809523823,
#    'weight': 2.3809523809523823}),
#  (32,
#   33,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.0985247629083248,
#    'score': 1.0985247629083248,
#    'weight': 1.0985247629083248}),
#  (32,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.886792452830188,
#    'score': 1.886792452830188,
#    'weight': 1.886792452830188}),
#  (32,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 16.66666666666673,
#    'score': 16.66666666666673,
#    'weight': 16.66666666666673}),
#  (32,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.225806451612905,
#    'score': 3.225806451612905,
#    'weight': 3.225806451612905}),
#  (32,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 33.33333333333361,
#    'score': 33.33333333333361,
#    'weight': 33.33333333333361}),
#  (32,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.941176470588233,
#    'score': 2.941176470588233,
#    'weight': 2.941176470588233}),
#  (32,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2820512820512817,
#    'score': 1.2820512820512817,
#    'weight': 1.2820512820512817}),
#  (32,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 25.00000000000015,
#    'score': 25.00000000000015,
#    'weight': 25.00000000000015}),
#  (32,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6289308176100629,
#    'score': 0.6289308176100629,
#    'weight': 0.6289308176100629}),
#  (32,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9259259259259258,
#    'score': 0.9259259259259258,
#    'weight': 0.9259259259259258}),
#  (32,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.500000000000032,
#    'score': 12.500000000000032,
#    'weight': 12.500000000000032}),
#  (33,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 99.99999999999713,
#    'score': 99.99999999999713,
#    'weight': 99.99999999999713}),
#  (33,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7241379310344835,
#    'score': 1.7241379310344835,
#    'weight': 1.7241379310344835}),
#  (33,
#   36,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.204819277108434,
#    'score': 1.204819277108434,
#    'weight': 1.204819277108434}),
#  (33,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.8181818181818195,
#    'score': 1.8181818181818195,
#    'weight': 1.8181818181818195}),
#  (33,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.555555555555568,
#    'score': 5.555555555555568,
#    'weight': 5.555555555555568}),
#  (33,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.8461538461538423,
#    'score': 3.8461538461538423,
#    'weight': 3.8461538461538423}),
#  (33,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.785714285714287,
#    'score': 1.785714285714287,
#    'weight': 1.785714285714287}),
#  (33,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9345794392523363,
#    'score': 0.9345794392523363,
#    'weight': 0.9345794392523363}),
#  (33,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.6666666666666674,
#    'score': 1.6666666666666674,
#    'weight': 1.6666666666666674}),
#  (33,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7857142857142851,
#    'score': 1.7857142857142851,
#    'weight': 1.7857142857142851}),
#  (34,
#   35,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.0124741287688093,
#    'score': 1.0124741287688093,
#    'weight': 1.0124741287688093}),
#  (34,
#   36,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.7418656612204998,
#    'score': 0.7418656612204998,
#    'weight': 0.7418656612204998}),
#  (34,
#   37,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.502613240418118,
#    'score': 1.502613240418118,
#    'weight': 1.502613240418118}),
#  (34,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736845,
#    'score': 5.263157894736845,
#    'weight': 5.263157894736845}),
#  (34,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.000000000000001,
#    'score': 4.000000000000001,
#    'weight': 4.000000000000001}),
#  (34,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.7543859649122808,
#    'score': 1.7543859649122808,
#    'weight': 1.7543859649122808}),
#  (34,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9433962264150946,
#    'score': 0.9433962264150946,
#    'weight': 0.9433962264150946}),
#  (34,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.8181818181818183,
#    'score': 1.8181818181818183,
#    'weight': 1.8181818181818183}),
#  (34,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.6393442622950818,
#    'score': 1.6393442622950818,
#    'weight': 1.6393442622950818}),
#  (35,
#   36,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.63157894736842,
#    'score': 2.510826616089773,
#    'weight': 2.510826616089773}),
#  (35,
#   37,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 16.79653679653678,
#    'score': 16.79653679653678,
#    'weight': 16.79653679653678}),
#  (35,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.4999999999999996,
#    'score': 2.4999999999999996,
#    'weight': 2.4999999999999996}),
#  (35,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761907,
#    'score': 1.1904761904761907,
#    'weight': 1.1904761904761907}),
#  (35,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (35,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6060606060606062,
#    'score': 0.6060606060606062,
#    'weight': 0.6060606060606062}),
#  (35,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 25.221238938053077,
#    'score': 25.221238938053077,
#    'weight': 25.221238938053077}),
#  (35,
#   43,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 0.46082949308755755,
#    'score': 0.5590018421303852,
#    'weight': 0.5590018421303852}),
#  (36,
#   37,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.9039175954069565,
#    'score': 1.9039175954069565,
#    'weight': 1.9039175954069565}),
#  (36,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.538461538461538,
#    'score': 1.538461538461538,
#    'weight': 1.538461538461538}),
#  (36,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9174311926605505,
#    'score': 0.9174311926605505,
#    'weight': 0.9174311926605505}),
#  (36,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.7037037037037024,
#    'score': 3.7037037037037024,
#    'weight': 3.7037037037037024}),
#  (36,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5263157894736843,
#    'score': 0.5263157894736843,
#    'weight': 0.5263157894736843}),
#  (36,
#   43,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.4828649395754332,
#    'score': 0.4828649395754332,
#    'weight': 0.4828649395754332}),
#  (36,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.347826086956521,
#    'score': 4.347826086956521,
#    'weight': 4.347826086956521}),
#  (37,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.7027027027027026,
#    'score': 2.7027027027027026,
#    'weight': 2.7027027027027026}),
#  (37,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.234567901234568,
#    'score': 1.234567901234568,
#    'weight': 1.234567901234568}),
#  (37,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (37,
#   41,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.617283950617284,
#    'score': 0.617283950617284,
#    'weight': 0.617283950617284}),
#  (37,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (37,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9009009009009009,
#    'score': 0.9009009009009009,
#    'weight': 0.9009009009009009}),
#  (38,
#   39,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.4960758665794642,
#    'score': 1.4960758665794642,
#    'weight': 1.4960758665794642}),
#  (38,
#   40,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.535301668806164,
#    'score': 2.535301668806164,
#    'weight': 2.535301668806164}),
#  (38,
#   41,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8999999999999999,
#    'score': 0.8999999999999999,
#    'weight': 0.8999999999999999}),
#  (38,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523805,
#    'score': 2.3809523809523805,
#    'weight': 2.3809523809523805}),
#  (38,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3513513513513518,
#    'score': 1.3513513513513518,
#    'weight': 1.3513513513513518}),
#  (39,
#   40,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 1.2195121951219514,
#    'score': 3.9250225835591706,
#    'weight': 3.9250225835591706}),
#  (39,
#   41,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.8993352326685669,
#    'score': 1.8993352326685669,
#    'weight': 1.8993352326685669}),
#  (39,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1627906976744187,
#    'score': 1.1627906976744187,
#    'weight': 1.1627906976744187}),
#  (39,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.3333333333333335,
#    'score': 3.3333333333333335,
#    'weight': 3.3333333333333335}),
#  (40,
#   41,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.6613583953356831,
#    'score': 0.6613583953356831,
#    'weight': 0.6613583953356831}),
#  (40,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (40,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8928571428571429,
#    'score': 0.8928571428571429,
#    'weight': 0.8928571428571429}),
#  (41,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.9607843137254908,
#    'score': 1.9607843137254908,
#    'weight': 1.9607843137254908}),
#  (41,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5988023952095809,
#    'score': 0.5988023952095809,
#    'weight': 0.5988023952095809}),
#  (42,
#   43,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 5.986590038314172,
#    'score': 5.986590038314172,
#    'weight': 5.986590038314172})]

# %% [markdown]
# ### See more about graph operations at NetworkX's page: at http://networkx.github.io/documentation/networkx-1.9/index.html

# %%
file2 ='files/verb_output/for_excel_verbs.csv'
df_v = pd.read_csv(file2)

# %%
df_v
# Out:
#      DocID    Topic  Score                          File     Author
# 0       42  Topic11  0.107    stevenson_treasure_ch1.txt  stevenson
# 1       42   Topic8  0.208    stevenson_treasure_ch1.txt  stevenson
# 2       42  Topic13  0.117    stevenson_treasure_ch1.txt  stevenson
# 3       42   Topic9  0.102    stevenson_treasure_ch1.txt  stevenson
# 4       42   Topic4  0.117    stevenson_treasure_ch1.txt  stevenson
# 5       43  Topic11  0.172    stevenson_treasure_ch2.txt  stevenson
# 6       43   Topic8  0.244    stevenson_treasure_ch2.txt  stevenson
# 7       43   Topic4  0.110    stevenson_treasure_ch2.txt  stevenson
# 8       24  Topic10  0.191     eliot_middlemarch_ch2.txt      eliot
# 9       24  Topic13  0.131     eliot_middlemarch_ch2.txt      eliot
# 10      24   Topic4  0.119     eliot_middlemarch_ch2.txt      eliot
# 11      25  Topic10  0.109    eliot_middlemarch_ch48.txt      eliot
# 12      25   Topic3  0.248    eliot_middlemarch_ch48.txt      eliot
# 13      26   Topic9  0.106    eliot_middlemarch_ch73.txt      eliot
# 14      26   Topic8  0.174    eliot_middlemarch_ch73.txt      eliot
# 15      26   Topic7  0.152    eliot_middlemarch_ch73.txt      eliot
# 16      27   Topic9  0.124   eljames_fiftyshades_ch1.txt    eljames
# 17      27  Topic10  0.107   eljames_fiftyshades_ch1.txt    eljames
# 18      27   Topic5  0.192   eljames_fiftyshades_ch1.txt    eljames
# 19      27  Topic14  0.216   eljames_fiftyshades_ch1.txt    eljames
# 20      27   Topic6  0.105   eljames_fiftyshades_ch1.txt    eljames
# 21      20  Topic13  0.144      doyle_caseofidentity.txt      doyle
# 22      20   Topic2  0.142      doyle_caseofidentity.txt      doyle
# 23      20   Topic3  0.120      doyle_caseofidentity.txt      doyle
# 24      21  Topic13  0.104     doyle_redheadedleague.txt      doyle
# 25      21   Topic2  0.238     doyle_redheadedleague.txt      doyle
# 26      22   Topic9  0.123      doyle_scandalbohemia.txt      doyle
# 27      22   Topic2  0.187      doyle_scandalbohemia.txt      doyle
# 28      23   Topic9  0.218     eliot_middlemarch_ch1.txt      eliot
# 29      23  Topic13  0.113     eliot_middlemarch_ch1.txt      eliot
# ..     ...      ...    ...                           ...        ...
# 95      16  Topic12  0.143        brown_davinci_ch77.txt      brown
# 96      19  Topic15  0.310         conrad_secret_ch2.txt     conrad
# 97      18  Topic13  0.142         conrad_secret_ch1.txt     conrad
# 98      18  Topic15  0.186         conrad_secret_ch1.txt     conrad
# 99      31  Topic11  0.340       grimms_hanselgretel.txt     grimms
# 100     31   Topic8  0.113       grimms_hanselgretel.txt     grimms
# 101     31   Topic2  0.158       grimms_hanselgretel.txt     grimms
# 102     30   Topic5  0.429  eljames_fiftyshades_ch23.txt    eljames
# 103     30  Topic14  0.177  eljames_fiftyshades_ch23.txt    eljames
# 104     30   Topic6  0.127  eljames_fiftyshades_ch23.txt    eljames
# 105     37  Topic13  0.152       lewis_lionwitch_ch2.txt      lewis
# 106     37   Topic4  0.117       lewis_lionwitch_ch2.txt      lewis
# 107     37   Topic6  0.211       lewis_lionwitch_ch2.txt      lewis
# 108     36  Topic11  0.160      lewis_lionwitch_ch14.txt      lewis
# 109     36   Topic1  0.117      lewis_lionwitch_ch14.txt      lewis
# 110     36  Topic13  0.146      lewis_lionwitch_ch14.txt      lewis
# 111     36  Topic14  0.113      lewis_lionwitch_ch14.txt      lewis
# 112     35  Topic11  0.153      lewis_lionwitch_ch12.txt      lewis
# 113     35   Topic1  0.111      lewis_lionwitch_ch12.txt      lewis
# 114     35  Topic13  0.168      lewis_lionwitch_ch12.txt      lewis
# 115     34   Topic1  0.110       lewis_lionwitch_ch1.txt      lewis
# 116     34  Topic13  0.237       lewis_lionwitch_ch1.txt      lewis
# 117     34  Topic12  0.153       lewis_lionwitch_ch1.txt      lewis
# 118     33   Topic8  0.307        grimms_wateroflife.txt     grimms
# 119     33  Topic13  0.104        grimms_wateroflife.txt     grimms
# 120     33   Topic2  0.108        grimms_wateroflife.txt     grimms
# 121     33  Topic10  0.124        grimms_wateroflife.txt     grimms
# 122     32  Topic11  0.267           grimms_snowdrop.txt     grimms
# 123     32   Topic8  0.178           grimms_snowdrop.txt     grimms
# 124     32  Topic13  0.111           grimms_snowdrop.txt     grimms
#
# [125 rows x 5 columns]

# %%
edges_verb = make_edges_dict(df_v)

# %%
for pair, weight in edges_verb.iteritems():  # if you haven't modified your dict, will be same order
    g.add_edge(pair[0],pair[1], weight=float(np.mean(weight)), score=float(np.mean(weight)), 
                   count=len(weight), median=float(np.median(weight)), label="verbs")

# %%
g.size()
# Out:
# 591

# %%
g.edges(data=True)
# Out:
# [(1,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.7037037037037046,
#    'score': 3.7037037037037046,
#    'weight': 3.7037037037037046}),
#  (1,
#   2,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.46082949308755755,
#    'score': 0.46082949308755755,
#    'weight': 0.46082949308755755}),
#  (1,
#   3,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.617919205596932,
#    'score': 2.617919205596932,
#    'weight': 2.617919205596932}),
#  (1,
#   4,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.8722943722943728,
#    'score': 1.8722943722943728,
#    'weight': 1.8722943722943728}),
#  (1,
#   5,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6711409395973154,
#    'score': 0.6711409395973154,
#    'weight': 0.6711409395973154}),
#  (1,
#   6,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.477225672877843,
#    'score': 4.477225672877843,
#    'weight': 4.477225672877843}),
#  (1,
#   7,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.42016806722689076,
#    'score': 0.42016806722689076,
#    'weight': 0.42016806722689076}),
#  (1,
#   8,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.4050684651543024,
#    'score': 1.4050684651543024,
#    'weight': 1.4050684651543024}),
#  (1,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0989010989010992,
#    'score': 1.0989010989010992,
#    'weight': 1.0989010989010992}),
#  (1,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.78125,
#    'score': 0.78125,
#    'weight': 0.78125}),
#  (1,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9009009009009009,
#    'score': 0.9009009009009009,
#    'weight': 0.9009009009009009}),
#  (1,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0204081632653061,
#    'score': 1.0204081632653061,
#    'weight': 1.0204081632653061}),
#  (1,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8771929824561404,
#    'score': 0.8771929824561404,
#    'weight': 0.8771929824561404}),
#  (1,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.5063076633402364,
#    'score': 1.5063076633402364,
#    'weight': 1.5063076633402364}),
#  (1,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.4999999999999996,
#    'score': 2.4999999999999996,
#    'weight': 2.4999999999999996}),
#  (1,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.3809523809523814,
#    'score': 2.3809523809523814,
#    'weight': 2.3809523809523814}),
#  (1,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.2801120448179272,
#    'score': 0.2801120448179272,
#    'weight': 0.2801120448179272}),
#  (1,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.272727272727273,
#    'score': 2.272727272727273,
#    'weight': 2.272727272727273}),
#  (1,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.127659574468086,
#    'score': 2.127659574468086,
#    'weight': 2.127659574468086}),
#  (2,
#   3,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (2,
#   4,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.1645021645021636,
#    'score': 2.1645021645021636,
#    'weight': 2.1645021645021636}),
#  (2,
#   5,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.4705882352941175,
#    'score': 1.4705882352941175,
#    'weight': 1.4705882352941175}),
#  (2,
#   6,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.7857142857142858,
#    'score': 1.7857142857142858,
#    'weight': 1.7857142857142858}),
#  (2,
#   7,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 6.227106227106232,
#    'score': 6.227106227106232,
#    'weight': 6.227106227106232}),
#  (2,
#   8,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 6.250000000000016,
#    'score': 6.250000000000016,
#    'weight': 6.250000000000016}),
#  (2,
#   9,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6849315068493149,
#    'score': 0.6849315068493149,
#    'weight': 0.6849315068493149}),
#  (2,
#   10,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.857142857142858,
#    'score': 2.857142857142858,
#    'weight': 2.857142857142858}),
#  (2,
#   11,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.3584229390681003,
#    'score': 0.3584229390681003,
#    'weight': 0.3584229390681003}),
#  (2,
#   16,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4807692307692307,
#    'score': 0.4807692307692307,
#    'weight': 0.4807692307692307}),
#  (2,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (2,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.4482758620689644,
#    'score': 3.4482758620689644,
#    'weight': 3.4482758620689644}),
#  (2,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 11.111111111111118,
#    'score': 11.111111111111118,
#    'weight': 11.111111111111118}),
#  (2,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.2258064516129017,
#    'score': 3.2258064516129017,
#    'weight': 3.2258064516129017}),
#  (2,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.166666666666666,
#    'score': 4.166666666666666,
#    'weight': 4.166666666666666}),
#  (2,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 12.49999999999999,
#    'score': 12.49999999999999,
#    'weight': 12.49999999999999}),
#  (2,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.72992700729927,
#    'score': 0.72992700729927,
#    'weight': 0.72992700729927}),
#  (2,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7142857142857143,
#    'score': 0.7142857142857143,
#    'weight': 0.7142857142857143}),
#  (2,
#   27,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.1988071570576541,
#    'score': 0.1988071570576541,
#    'weight': 0.1988071570576541}),
#  (2,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0101010101010104,
#    'score': 1.0101010101010104,
#    'weight': 1.0101010101010104}),
#  (2,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.666666666666693,
#    'score': 16.666666666666693,
#    'weight': 16.666666666666693}),
#  (2,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.666666666666693,
#    'score': 16.666666666666693,
#    'weight': 16.666666666666693}),
#  (2,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (3,
#   4,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.870892018779344,
#    'score': 4.870892018779344,
#    'weight': 4.870892018779344}),
#  (3,
#   5,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6129032258064515,
#    'score': 1.6129032258064515,
#    'weight': 1.6129032258064515}),
#  (3,
#   6,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.5151515151515156,
#    'score': 2.5151515151515156,
#    'weight': 2.5151515151515156}),
#  (3,
#   7,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.703703703703708,
#    'score': 3.703703703703708,
#    'weight': 3.703703703703708}),
#  (3,
#   8,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.6536796536796565,
#    'score': 4.6536796536796565,
#    'weight': 4.6536796536796565}),
#  (3,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.225806451612903,
#    'score': 3.225806451612903,
#    'weight': 3.225806451612903}),
#  (3,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.265822784810126,
#    'score': 1.265822784810126,
#    'weight': 1.265822784810126}),
#  (3,
#   19,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4926108374384236,
#    'score': 0.4926108374384236,
#    'weight': 0.4926108374384236}),
#  (3,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.763358778625954,
#    'score': 0.763358778625954,
#    'weight': 0.763358778625954}),
#  (3,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.142857142857143,
#    'score': 7.142857142857143,
#    'weight': 7.142857142857143}),
#  (3,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6802721088435373,
#    'score': 0.6802721088435373,
#    'weight': 0.6802721088435373}),
#  (3,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.3809523809523814,
#    'score': 2.3809523809523814,
#    'weight': 2.3809523809523814}),
#  (3,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6393442622950818,
#    'score': 1.6393442622950818,
#    'weight': 1.6393442622950818}),
#  (3,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.761904761904761,
#    'score': 4.761904761904761,
#    'weight': 4.761904761904761}),
#  (3,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6849315068493151,
#    'score': 0.6849315068493151,
#    'weight': 0.6849315068493151}),
#  (3,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.347826086956521,
#    'score': 4.347826086956521,
#    'weight': 4.347826086956521}),
#  (3,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.8461538461538467,
#    'score': 3.8461538461538467,
#    'weight': 3.8461538461538467}),
#  (3,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 33.33333333333346,
#    'score': 33.33333333333346,
#    'weight': 33.33333333333346}),
#  (3,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (3,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 10.000000000000005,
#    'score': 10.000000000000005,
#    'weight': 10.000000000000005}),
#  (3,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (3,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8064516129032258,
#    'score': 0.8064516129032258,
#    'weight': 0.8064516129032258}),
#  (4,
#   5,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 11.111111111111102,
#    'score': 11.111111111111102,
#    'weight': 11.111111111111102}),
#  (4,
#   6,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.49206349206349,
#    'score': 3.49206349206349,
#    'weight': 3.49206349206349}),
#  (4,
#   7,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.0102040816326507,
#    'score': 3.0102040816326507,
#    'weight': 3.0102040816326507}),
#  (4,
#   8,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 6.093189964157702,
#    'score': 6.093189964157702,
#    'weight': 6.093189964157702}),
#  (4,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761907,
#    'score': 1.1904761904761907,
#    'weight': 1.1904761904761907}),
#  (4,
#   16,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5714285714285714,
#    'score': 0.5714285714285714,
#    'weight': 0.5714285714285714}),
#  (4,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.666666666666693,
#    'score': 16.666666666666693,
#    'weight': 16.666666666666693}),
#  (4,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8264462809917354,
#    'score': 0.8264462809917354,
#    'weight': 0.8264462809917354}),
#  (4,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9615384615384615,
#    'score': 0.9615384615384615,
#    'weight': 0.9615384615384615}),
#  (4,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.1666666666666625,
#    'score': 4.1666666666666625,
#    'weight': 4.1666666666666625}),
#  (4,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9345794392523363,
#    'score': 0.9345794392523363,
#    'weight': 0.9345794392523363}),
#  (4,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.0151763740771118,
#    'score': 1.0151763740771118,
#    'weight': 1.0151763740771118}),
#  (4,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.3698630136986303,
#    'score': 1.3698630136986303,
#    'weight': 1.3698630136986303}),
#  (4,
#   25,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 6.036324786324782,
#    'score': 6.036324786324782,
#    'weight': 6.036324786324782}),
#  (4,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.46082949308755766,
#    'score': 0.46082949308755766,
#    'weight': 0.46082949308755766}),
#  (4,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 9.090909090909083,
#    'score': 9.090909090909083,
#    'weight': 9.090909090909083}),
#  (4,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.142857142857143,
#    'score': 7.142857142857143,
#    'weight': 7.142857142857143}),
#  (5,
#   6,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333325,
#    'score': 8.333333333333325,
#    'weight': 8.333333333333325}),
#  (5,
#   7,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.123595505617978,
#    'score': 1.123595505617978,
#    'weight': 1.123595505617978}),
#  (5,
#   8,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.1904761904761911,
#    'score': 1.1904761904761911,
#    'weight': 1.1904761904761911}),
#  (5,
#   9,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.8181818181818183,
#    'score': 1.8181818181818183,
#    'weight': 1.8181818181818183}),
#  (5,
#   12,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.166666666666668,
#    'score': 4.166666666666668,
#    'weight': 4.166666666666668}),
#  (5,
#   13,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6393442622950816,
#    'score': 1.6393442622950816,
#    'weight': 1.6393442622950816}),
#  (5,
#   15,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (5,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.8461538461538423,
#    'score': 3.8461538461538423,
#    'weight': 3.8461538461538423}),
#  (5,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6060606060606062,
#    'score': 0.6060606060606062,
#    'weight': 0.6060606060606062}),
#  (5,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.166666666666668,
#    'score': 4.166666666666668,
#    'weight': 4.166666666666668}),
#  (5,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5625,
#    'score': 1.5625,
#    'weight': 1.5625}),
#  (5,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.5952380952380953,
#    'score': 0.5952380952380953,
#    'weight': 0.5952380952380953}),
#  (5,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.818181818181818,
#    'score': 1.818181818181818,
#    'weight': 1.818181818181818}),
#  (5,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.7027027027027026,
#    'score': 2.7027027027027026,
#    'weight': 2.7027027027027026}),
#  (5,
#   25,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.5950657788928561,
#    'score': 0.5950657788928561,
#    'weight': 0.5950657788928561}),
#  (5,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4807692307692307,
#    'score': 0.4807692307692307,
#    'weight': 0.4807692307692307}),
#  (5,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.7543859649122804,
#    'score': 1.7543859649122804,
#    'weight': 1.7543859649122804}),
#  (5,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5625,
#    'score': 1.5625,
#    'weight': 1.5625}),
#  (5,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.449275362318841,
#    'score': 1.449275362318841,
#    'weight': 1.449275362318841}),
#  (5,
#   35,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (5,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.545454545454541,
#    'score': 4.545454545454541,
#    'weight': 4.545454545454541}),
#  (5,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 6.249999999999995,
#    'score': 6.249999999999995,
#    'weight': 6.249999999999995}),
#  (5,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.7543859649122804,
#    'score': 1.7543859649122804,
#    'weight': 1.7543859649122804}),
#  (5,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.9607843137254897,
#    'score': 1.9607843137254897,
#    'weight': 1.9607843137254897}),
#  (6,
#   7,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2987012987012994,
#    'score': 1.2987012987012994,
#    'weight': 1.2987012987012994}),
#  (6,
#   8,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.6203703703703707,
#    'score': 1.6203703703703707,
#    'weight': 1.6203703703703707}),
#  (6,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4716981132075471,
#    'score': 0.4716981132075471,
#    'weight': 0.4716981132075471}),
#  (6,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.5641025641025634,
#    'score': 2.5641025641025634,
#    'weight': 2.5641025641025634}),
#  (6,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4016064257028112,
#    'score': 0.4016064257028112,
#    'weight': 0.4016064257028112}),
#  (6,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.43103448275862066,
#    'score': 0.43103448275862066,
#    'weight': 0.43103448275862066}),
#  (6,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4566210045662099,
#    'score': 0.4566210045662099,
#    'weight': 0.4566210045662099}),
#  (6,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4255319148936169,
#    'score': 0.4255319148936169,
#    'weight': 0.4255319148936169}),
#  (6,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.387588257153478,
#    'score': 2.387588257153478,
#    'weight': 2.387588257153478}),
#  (6,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.5714285714285716,
#    'score': 3.5714285714285716,
#    'weight': 3.5714285714285716}),
#  (6,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.8518518518518516,
#    'score': 1.8518518518518516,
#    'weight': 1.8518518518518516}),
#  (6,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5102040816326532,
#    'score': 0.5102040816326532,
#    'weight': 0.5102040816326532}),
#  (6,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.7857142857142854,
#    'score': 1.7857142857142854,
#    'weight': 1.7857142857142854}),
#  (6,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6949152542372883,
#    'score': 1.6949152542372883,
#    'weight': 1.6949152542372883}),
#  (7,
#   8,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (7,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.1739130434782616,
#    'score': 2.1739130434782616,
#    'weight': 2.1739130434782616}),
#  (7,
#   16,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5128205128205128,
#    'score': 0.5128205128205128,
#    'weight': 0.5128205128205128}),
#  (7,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2048192771084336,
#    'score': 1.2048192771084336,
#    'weight': 1.2048192771084336}),
#  (7,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.5151515151515151,
#    'score': 1.5151515151515151,
#    'weight': 1.5151515151515151}),
#  (7,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (7,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4492753623188404,
#    'score': 1.4492753623188404,
#    'weight': 1.4492753623188404}),
#  (7,
#   23,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.4928698752228158,
#    'score': 1.4928698752228158,
#    'weight': 1.4928698752228158}),
#  (7,
#   24,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 2.1739130434782603,
#    'score': 2.1739130434782603,
#    'weight': 2.1739130434782603}),
#  (7,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8064516129032258,
#    'score': 0.8064516129032258,
#    'weight': 0.8064516129032258}),
#  (7,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8403361344537814,
#    'score': 0.8403361344537814,
#    'weight': 0.8403361344537814}),
#  (8,
#   14,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.8461538461538467,
#    'score': 3.8461538461538467,
#    'weight': 3.8461538461538467}),
#  (8,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6024096385542167,
#    'score': 0.6024096385542167,
#    'weight': 0.6024096385542167}),
#  (8,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6711409395973154,
#    'score': 0.6711409395973154,
#    'weight': 0.6711409395973154}),
#  (8,
#   20,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7352941176470587,
#    'score': 0.7352941176470587,
#    'weight': 0.7352941176470587}),
#  (8,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.263157894736841,
#    'score': 5.263157894736841,
#    'weight': 5.263157894736841}),
#  (8,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.6578947368421051,
#    'score': 0.6578947368421051,
#    'weight': 0.6578947368421051}),
#  (8,
#   23,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.7027027027027004,
#    'score': 2.3121276432534703,
#    'weight': 2.3121276432534703}),
#  (8,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2195121951219512,
#    'score': 1.2195121951219512,
#    'weight': 1.2195121951219512}),
#  (8,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (8,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8064516129032256,
#    'score': 0.8064516129032256,
#    'weight': 0.8064516129032256}),
#  (8,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (8,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 20.000000000000036,
#    'score': 20.000000000000036,
#    'weight': 20.000000000000036}),
#  (8,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.50000000000001,
#    'score': 12.50000000000001,
#    'weight': 12.50000000000001}),
#  (8,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 6.666666666666667,
#    'score': 6.666666666666667,
#    'weight': 6.666666666666667}),
#  (8,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 6.666666666666667,
#    'score': 6.666666666666667,
#    'weight': 6.666666666666667}),
#  (8,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (8,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7751937984496123,
#    'score': 0.7751937984496123,
#    'weight': 0.7751937984496123}),
#  (9,
#   10,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.6798082486155881,
#    'score': 0.6798082486155881,
#    'weight': 0.6798082486155881}),
#  (9,
#   11,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 5.931495405179611,
#    'score': 5.931495405179611,
#    'weight': 5.931495405179611}),
#  (9,
#   12,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2658227848101267,
#    'score': 1.2658227848101267,
#    'weight': 1.2658227848101267}),
#  (9,
#   13,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8620689655172413,
#    'score': 0.8620689655172413,
#    'weight': 0.8620689655172413}),
#  (9,
#   14,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 12.49999999999999,
#    'score': 12.49999999999999,
#    'weight': 12.49999999999999}),
#  (9,
#   15,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.8867924528301891,
#    'score': 1.8867924528301891,
#    'weight': 1.8867924528301891}),
#  (9,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6578947368421051,
#    'score': 0.6578947368421051,
#    'weight': 0.6578947368421051}),
#  (9,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2345679012345676,
#    'score': 1.2345679012345676,
#    'weight': 1.2345679012345676}),
#  (9,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2658227848101267,
#    'score': 1.2658227848101267,
#    'weight': 1.2658227848101267}),
#  (9,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8403361344537815,
#    'score': 0.8403361344537815,
#    'weight': 0.8403361344537815}),
#  (9,
#   23,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.8643815201192251,
#    'score': 0.8643815201192251,
#    'weight': 0.8643815201192251}),
#  (9,
#   24,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.9057971014492753,
#    'score': 0.9057971014492753,
#    'weight': 0.9057971014492753}),
#  (9,
#   31,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4651162790697674,
#    'score': 0.4651162790697674,
#    'weight': 0.4651162790697674}),
#  (9,
#   32,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.7985412474849094,
#    'score': 0.7985412474849094,
#    'weight': 0.7985412474849094}),
#  (9,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8403361344537815,
#    'score': 0.8403361344537815,
#    'weight': 0.8403361344537815}),
#  (9,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.14285714285715,
#    'score': 7.14285714285715,
#    'weight': 7.14285714285715}),
#  (9,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.6948051948051948,
#    'score': 2.6948051948051948,
#    'weight': 2.6948051948051948}),
#  (9,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.0779220779220777,
#    'score': 2.0779220779220777,
#    'weight': 2.0779220779220777}),
#  (9,
#   37,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.0613682092555332,
#    'score': 1.0613682092555332,
#    'weight': 1.0613682092555332}),
#  (9,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8928571428571429,
#    'score': 0.8928571428571429,
#    'weight': 0.8928571428571429}),
#  (9,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333336,
#    'score': 8.333333333333336,
#    'weight': 8.333333333333336}),
#  (9,
#   42,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 0.9433962264150942,
#    'score': 2.4044124987521216,
#    'weight': 2.4044124987521216}),
#  (9,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.4039658416558116,
#    'score': 1.4039658416558116,
#    'weight': 1.4039658416558116}),
#  (10,
#   11,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.425182349967502,
#    'score': 0.425182349967502,
#    'weight': 0.425182349967502}),
#  (10,
#   14,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4761904761904763,
#    'score': 0.4761904761904763,
#    'weight': 0.4761904761904763}),
#  (10,
#   15,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (10,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.439024390243903,
#    'score': 2.439024390243903,
#    'weight': 2.439024390243903}),
#  (10,
#   18,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 12.50000000000001,
#    'score': 12.50000000000001,
#    'weight': 12.50000000000001}),
#  (10,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.846153846153849,
#    'score': 3.846153846153849,
#    'weight': 3.846153846153849}),
#  (10,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (10,
#   22,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 9.090909090909095,
#    'score': 9.090909090909095,
#    'weight': 9.090909090909095}),
#  (10,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 9.090909090909106,
#    'score': 9.090909090909106,
#    'weight': 9.090909090909106}),
#  (10,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.703703703703706,
#    'score': 3.703703703703706,
#    'weight': 3.703703703703706}),
#  (10,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.142857142857136,
#    'score': 7.142857142857136,
#    'weight': 7.142857142857136}),
#  (10,
#   29,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8474576271186445,
#    'score': 0.8474576271186445,
#    'weight': 0.8474576271186445}),
#  (10,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4925373134328355,
#    'score': 1.4925373134328355,
#    'weight': 1.4925373134328355}),
#  (10,
#   31,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 33.333333333333925,
#    'score': 33.333333333333925,
#    'weight': 33.333333333333925}),
#  (10,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.3157894736842113,
#    'score': 1.3157894736842113,
#    'weight': 1.3157894736842113}),
#  (10,
#   33,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.204819277108434,
#    'score': 1.204819277108434,
#    'weight': 1.204819277108434}),
#  (10,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1904761904761902,
#    'score': 1.1904761904761902,
#    'weight': 1.1904761904761902}),
#  (10,
#   35,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5263157894736843,
#    'score': 0.5263157894736843,
#    'weight': 0.5263157894736843}),
#  (10,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.546448087431694,
#    'score': 0.546448087431694,
#    'weight': 0.546448087431694}),
#  (10,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.4482758620689657,
#    'score': 3.4482758620689657,
#    'weight': 3.4482758620689657}),
#  (10,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.538461538461538,
#    'score': 1.538461538461538,
#    'weight': 1.538461538461538}),
#  (10,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9174311926605505,
#    'score': 0.9174311926605505,
#    'weight': 0.9174311926605505}),
#  (10,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.7037037037037024,
#    'score': 3.7037037037037024,
#    'weight': 3.7037037037037024}),
#  (10,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.4347826086956522,
#    'score': 0.4347826086956522,
#    'weight': 0.4347826086956522}),
#  (10,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.936002337814144,
#    'score': 1.936002337814144,
#    'weight': 1.936002337814144}),
#  (10,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.6812865497076026,
#    'score': 1.6812865497076026,
#    'weight': 1.6812865497076026}),
#  (11,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.662251655629139,
#    'score': 0.662251655629139,
#    'weight': 0.662251655629139}),
#  (11,
#   35,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.7027027027027026,
#    'score': 2.7027027027027026,
#    'weight': 2.7027027027027026}),
#  (11,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.2727272727272725,
#    'score': 2.2727272727272725,
#    'weight': 2.2727272727272725}),
#  (11,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.3663003663003663,
#    'score': 0.3663003663003663,
#    'weight': 0.3663003663003663}),
#  (11,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.0714285714285714,
#    'score': 1.0714285714285714,
#    'weight': 1.0714285714285714}),
#  (11,
#   14,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.882352941176466,
#    'score': 5.882352941176466,
#    'weight': 5.882352941176466}),
#  (11,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.3508771929824561,
#    'score': 0.3508771929824561,
#    'weight': 0.3508771929824561}),
#  (11,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 33.33333333333346,
#    'score': 33.33333333333346,
#    'weight': 33.33333333333346}),
#  (11,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.39215686274509803,
#    'score': 0.39215686274509803,
#    'weight': 0.39215686274509803}),
#  (11,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.36900369003690037,
#    'score': 0.36900369003690037,
#    'weight': 0.36900369003690037}),
#  (11,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 5.738705738705742,
#    'score': 5.738705738705742,
#    'weight': 5.738705738705742}),
#  (11,
#   31,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.44642857142857134,
#    'score': 0.44642857142857134,
#    'weight': 0.44642857142857134}),
#  (12,
#   13,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.6846846846846875,
#    'score': 4.6846846846846875,
#    'weight': 4.6846846846846875}),
#  (12,
#   14,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.263157894736845,
#    'score': 5.263157894736845,
#    'weight': 5.263157894736845}),
#  (12,
#   15,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 14.285714285714272,
#    'score': 39.377289377289344,
#    'weight': 39.377289377289344}),
#  (12,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4219409282700422,
#    'score': 0.4219409282700422,
#    'weight': 0.4219409282700422}),
#  (12,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4651162790697675,
#    'score': 0.4651162790697675,
#    'weight': 0.4651162790697675}),
#  (12,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 49.99999999999926,
#    'score': 49.99999999999926,
#    'weight': 49.99999999999926}),
#  (12,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (12,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.4999999999999996,
#    'score': 2.4999999999999996,
#    'weight': 2.4999999999999996}),
#  (12,
#   22,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 11.111111111111102,
#    'score': 11.111111111111102,
#    'weight': 11.111111111111102}),
#  (12,
#   23,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.0936724565756815,
#    'score': 2.0936724565756815,
#    'weight': 2.0936724565756815}),
#  (12,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.6923076923076845,
#    'score': 7.6923076923076845,
#    'weight': 7.6923076923076845}),
#  (12,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 12.49999999999999,
#    'score': 12.49999999999999,
#    'weight': 12.49999999999999}),
#  (12,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 10.000000000000005,
#    'score': 10.000000000000005,
#    'weight': 10.000000000000005}),
#  (12,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (12,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.030303030303029,
#    'score': 3.030303030303029,
#    'weight': 3.030303030303029}),
#  (12,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.4999999999999996,
#    'score': 2.4999999999999996,
#    'weight': 2.4999999999999996}),
#  (12,
#   34,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.7281105990783414,
#    'score': 1.7281105990783414,
#    'weight': 1.7281105990783414}),
#  (12,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.3028455284552853,
#    'score': 3.3028455284552853,
#    'weight': 3.3028455284552853}),
#  (12,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 26.42857142857175,
#    'score': 26.42857142857175,
#    'weight': 26.42857142857175}),
#  (12,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 12.500000000000032,
#    'score': 12.500000000000032,
#    'weight': 12.500000000000032}),
#  (12,
#   38,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.9216555801921649,
#    'score': 1.9216555801921649,
#    'weight': 1.9216555801921649}),
#  (12,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.7777777777777777,
#    'score': 2.7777777777777777,
#    'weight': 2.7777777777777777}),
#  (12,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.127659574468086,
#    'score': 2.127659574468086,
#    'weight': 2.127659574468086}),
#  (12,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (12,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 6.018518518518513,
#    'score': 6.018518518518513,
#    'weight': 6.018518518518513}),
#  (13,
#   14,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 51.47058823529407,
#    'score': 51.47058823529407,
#    'weight': 51.47058823529407}),
#  (13,
#   15,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.0663780663780673,
#    'score': 3.0663780663780673,
#    'weight': 3.0663780663780673}),
#  (13,
#   16,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3676470588235295,
#    'score': 0.3676470588235295,
#    'weight': 0.3676470588235295}),
#  (13,
#   17,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.4000000000000001,
#    'score': 0.4000000000000001,
#    'weight': 0.4000000000000001}),
#  (13,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.857142857142858,
#    'score': 2.857142857142858,
#    'weight': 2.857142857142858}),
#  (13,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.7027027027027013,
#    'score': 2.7027027027027013,
#    'weight': 2.7027027027027013}),
#  (13,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 33.33333333333346,
#    'score': 33.33333333333346,
#    'weight': 33.33333333333346}),
#  (13,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (13,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.166666666666666,
#    'score': 4.166666666666666,
#    'weight': 4.166666666666666}),
#  (13,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (13,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5882352941176471,
#    'score': 0.5882352941176471,
#    'weight': 0.5882352941176471}),
#  (13,
#   30,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.999999999999999,
#    'score': 4.999999999999999,
#    'weight': 4.999999999999999}),
#  (13,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (13,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 33.33333333333346,
#    'score': 33.33333333333346,
#    'weight': 33.33333333333346}),
#  (13,
#   34,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.2618083670715252,
#    'score': 1.2618083670715252,
#    'weight': 1.2618083670715252}),
#  (13,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.712529274004684,
#    'score': 1.712529274004684,
#    'weight': 1.712529274004684}),
#  (13,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.282051282051283,
#    'score': 2.282051282051283,
#    'weight': 2.282051282051283}),
#  (13,
#   37,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.5918803418803418,
#    'score': 1.5918803418803418,
#    'weight': 1.5918803418803418}),
#  (13,
#   38,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 12.962962962962951,
#    'score': 12.962962962962951,
#    'weight': 12.962962962962951}),
#  (13,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.9607843137254908,
#    'score': 1.9607843137254908,
#    'weight': 1.9607843137254908}),
#  (13,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.125,
#    'score': 3.125,
#    'weight': 3.125}),
#  (13,
#   41,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 5.549450549450558,
#    'score': 5.549450549450558,
#    'weight': 5.549450549450558}),
#  (13,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 10.000000000000005,
#    'score': 10.000000000000005,
#    'weight': 10.000000000000005}),
#  (14,
#   15,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 11.30952380952381,
#    'score': 11.30952380952381,
#    'weight': 11.30952380952381}),
#  (14,
#   16,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.7027027027027013,
#    'score': 2.7027027027027013,
#    'weight': 2.7027027027027013}),
#  (14,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6289308176100628,
#    'score': 0.6289308176100628,
#    'weight': 0.6289308176100628}),
#  (14,
#   21,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.2222222222222223,
#    'score': 2.2222222222222223,
#    'weight': 2.2222222222222223}),
#  (14,
#   23,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (14,
#   24,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 4.545454545454548,
#    'score': 4.545454545454548,
#    'weight': 4.545454545454548}),
#  (14,
#   25,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.0526315789473686,
#    'score': 1.0526315789473686,
#    'weight': 1.0526315789473686}),
#  (14,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666673,
#    'score': 16.66666666666673,
#    'weight': 16.66666666666673}),
#  (14,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (14,
#   28,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.28409090909090906,
#    'score': 0.28409090909090906,
#    'weight': 0.28409090909090906}),
#  (14,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5847953216374269,
#    'score': 0.5847953216374269,
#    'weight': 0.5847953216374269}),
#  (14,
#   30,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.761904761904761,
#    'score': 4.761904761904761,
#    'weight': 4.761904761904761}),
#  (14,
#   31,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.1506368028107157,
#    'score': 1.1506368028107157,
#    'weight': 1.1506368028107157}),
#  (14,
#   32,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 5.373134328358205,
#    'score': 5.373134328358205,
#    'weight': 5.373134328358205}),
#  (14,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7194244604316548,
#    'score': 0.7194244604316548,
#    'weight': 0.7194244604316548}),
#  (14,
#   34,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.237742830712303,
#    'score': 3.237742830712303,
#    'weight': 3.237742830712303}),
#  (14,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.772727272727273,
#    'score': 4.772727272727273,
#    'weight': 4.772727272727273}),
#  (14,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.976851851851849,
#    'score': 4.976851851851849,
#    'weight': 4.976851851851849}),
#  (14,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.9523809523809522,
#    'score': 0.9523809523809522,
#    'weight': 0.9523809523809522}),
#  (14,
#   38,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.9836916234247584,
#    'score': 2.9836916234247584,
#    'weight': 2.9836916234247584}),
#  (14,
#   39,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.2129156010230155,
#    'score': 3.2129156010230155,
#    'weight': 3.2129156010230155}),
#  (14,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.041666666666667,
#    'score': 1.041666666666667,
#    'weight': 1.041666666666667}),
#  (14,
#   41,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 4.166666666666668,
#    'score': 3.417874396135266,
#    'weight': 3.417874396135266}),
#  (14,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.173076923076922,
#    'score': 3.173076923076922,
#    'weight': 3.173076923076922}),
#  (14,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.9399460188933881,
#    'score': 1.9399460188933881,
#    'weight': 1.9399460188933881}),
#  (15,
#   16,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.333333333333332,
#    'score': 3.333333333333332,
#    'weight': 3.333333333333332}),
#  (15,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6578947368421051,
#    'score': 0.6578947368421051,
#    'weight': 0.6578947368421051}),
#  (15,
#   18,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.571428571428568,
#    'score': 3.571428571428568,
#    'weight': 3.571428571428568}),
#  (15,
#   19,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.1250000000000013,
#    'score': 3.1250000000000013,
#    'weight': 3.1250000000000013}),
#  (15,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.8461538461538467,
#    'score': 3.8461538461538467,
#    'weight': 3.8461538461538467}),
#  (15,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5151515151515151,
#    'score': 1.5151515151515151,
#    'weight': 1.5151515151515151}),
#  (15,
#   22,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 9.999999999999991,
#    'score': 9.999999999999991,
#    'weight': 9.999999999999991}),
#  (15,
#   23,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.3533834586466162,
#    'score': 1.3533834586466162,
#    'weight': 1.3533834586466162}),
#  (15,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.5641025641025634,
#    'score': 2.5641025641025634,
#    'weight': 2.5641025641025634}),
#  (15,
#   26,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 14.285714285714272,
#    'score': 14.285714285714272,
#    'weight': 14.285714285714272}),
#  (15,
#   27,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 9.090909090909095,
#    'score': 9.090909090909095,
#    'weight': 9.090909090909095}),
#  (15,
#   29,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (15,
#   30,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3698630136986298,
#    'score': 1.3698630136986298,
#    'weight': 1.3698630136986298}),
#  (15,
#   31,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.9708737864077668,
#    'score': 0.9708737864077668,
#    'weight': 0.9708737864077668}),
#  (15,
#   32,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6949152542372878,
#    'score': 1.6949152542372878,
#    'weight': 1.6949152542372878}),
#  (15,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5151515151515151,
#    'score': 1.5151515151515151,
#    'weight': 1.5151515151515151}),
#  (15,
#   34,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 2.5000000000000004,
#    'score': 2.2832267235252317,
#    'weight': 2.2832267235252317}),
#  (15,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 26.470588235294098,
#    'score': 26.470588235294098,
#    'weight': 26.470588235294098}),
#  (15,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.869047619047617,
#    'score': 3.869047619047617,
#    'weight': 3.869047619047617}),
#  (15,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.555555555555551,
#    'score': 5.555555555555551,
#    'weight': 5.555555555555551}),
#  (15,
#   38,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 1.6949152542372878,
#    'score': 3.5991597856004636,
#    'weight': 3.5991597856004636}),
#  (15,
#   39,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.0066238067406976,
#    'score': 2.0066238067406976,
#    'weight': 2.0066238067406976}),
#  (15,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.2217839140916067,
#    'score': 1.2217839140916067,
#    'weight': 1.2217839140916067}),
#  (15,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333325,
#    'score': 8.333333333333325,
#    'weight': 8.333333333333325}),
#  (15,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 5.488850771869635,
#    'score': 5.488850771869635,
#    'weight': 5.488850771869635}),
#  (15,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.689655172413793,
#    'score': 0.689655172413793,
#    'weight': 0.689655172413793}),
#  (16,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 10.000000000000018,
#    'score': 10.000000000000018,
#    'weight': 10.000000000000018}),
#  (16,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.555555555555551,
#    'score': 5.555555555555551,
#    'weight': 5.555555555555551}),
#  (16,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7194244604316549,
#    'score': 0.7194244604316549,
#    'weight': 0.7194244604316549}),
#  (16,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6802721088435375,
#    'score': 0.6802721088435375,
#    'weight': 0.6802721088435375}),
#  (16,
#   17,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8196721311475409,
#    'score': 0.8196721311475409,
#    'weight': 0.8196721311475409}),
#  (16,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5025125628140703,
#    'score': 0.5025125628140703,
#    'weight': 0.5025125628140703}),
#  (16,
#   25,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.408450704225352,
#    'score': 1.408450704225352,
#    'weight': 1.408450704225352}),
#  (17,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8928571428571427,
#    'score': 0.8928571428571427,
#    'weight': 0.8928571428571427}),
#  (17,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333336,
#    'score': 8.333333333333336,
#    'weight': 8.333333333333336}),
#  (17,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7142857142857142,
#    'score': 0.7142857142857142,
#    'weight': 0.7142857142857142}),
#  (17,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.000000000000005,
#    'score': 4.000000000000005,
#    'weight': 4.000000000000005}),
#  (17,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.882352941176484,
#    'score': 5.882352941176484,
#    'weight': 5.882352941176484}),
#  (17,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 19.999999999999982,
#    'score': 19.999999999999982,
#    'weight': 19.999999999999982}),
#  (17,
#   23,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 3.333333333333332,
#    'score': 3.333333333333332,
#    'weight': 3.333333333333332}),
#  (17,
#   24,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.142857142857136,
#    'score': 7.142857142857136,
#    'weight': 7.142857142857136}),
#  (17,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333336,
#    'score': 8.333333333333336,
#    'weight': 8.333333333333336}),
#  (18,
#   19,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.806451612903226,
#    'score': 0.806451612903226,
#    'weight': 0.806451612903226}),
#  (18,
#   20,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 49.99999999999926,
#    'score': 49.99999999999926,
#    'weight': 49.99999999999926}),
#  (18,
#   21,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.6315789473684226,
#    'score': 2.6315789473684226,
#    'weight': 2.6315789473684226}),
#  (18,
#   22,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 7.142857142857143,
#    'score': 20.802005012531314,
#    'weight': 20.802005012531314}),
#  (18,
#   23,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 3.075489282385834,
#    'score': 3.075489282385834,
#    'weight': 3.075489282385834}),
#  (18,
#   24,
#   {'count': 1,
#    'label': 'verbs',
# ...
#    'weight': 0.9090909090909088}),
#  (27,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.075268817204301,
#    'score': 1.075268817204301,
#    'weight': 1.075268817204301}),
#  (27,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 4.545454545454545,
#    'score': 4.545454545454545,
#    'weight': 4.545454545454545}),
#  (28,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.28735632183908044,
#    'score': 0.28735632183908044,
#    'weight': 0.28735632183908044}),
#  (28,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (28,
#   42,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 0.8484325568018407,
#    'score': 0.8484325568018407,
#    'weight': 0.8484325568018407}),
#  (28,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.7633587786259541,
#    'score': 0.7633587786259541,
#    'weight': 0.7633587786259541}),
#  (28,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.6923076923076845,
#    'score': 7.6923076923076845,
#    'weight': 7.6923076923076845}),
#  (28,
#   29,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.5619047619047624,
#    'score': 1.5619047619047624,
#    'weight': 1.5619047619047624}),
#  (28,
#   30,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.300665456745312,
#    'score': 1.300665456745312,
#    'weight': 1.300665456745312}),
#  (29,
#   30,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 0.6666666666666667,
#    'score': 1.7992115053584323,
#    'weight': 1.7992115053584323}),
#  (29,
#   33,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.000000000000003,
#    'score': 5.000000000000003,
#    'weight': 5.000000000000003}),
#  (29,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.20833333333333334,
#    'score': 0.20833333333333334,
#    'weight': 0.20833333333333334}),
#  (29,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.439024390243903,
#    'score': 2.439024390243903,
#    'weight': 2.439024390243903}),
#  (29,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5151515151515162,
#    'score': 1.5151515151515162,
#    'weight': 1.5151515151515162}),
#  (29,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.083333333333333,
#    'score': 2.083333333333333,
#    'weight': 2.083333333333333}),
#  (29,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.2658227848101273,
#    'score': 1.2658227848101273,
#    'weight': 1.2658227848101273}),
#  (29,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 6.249999999999995,
#    'score': 6.249999999999995,
#    'weight': 6.249999999999995}),
#  (29,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.3802281368821293,
#    'score': 0.3802281368821293,
#    'weight': 0.3802281368821293}),
#  (30,
#   31,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 1.7938931297709924,
#    'score': 1.7938931297709924,
#    'weight': 1.7938931297709924}),
#  (30,
#   32,
#   {'count': 3,
#    'label': 'allwords',
#    'median': 2.7777777777777755,
#    'score': 3.7414110943522707,
#    'weight': 3.7414110943522707}),
#  (30,
#   33,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 3.255890052356029,
#    'score': 3.255890052356029,
#    'weight': 3.255890052356029}),
#  (30,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 5.8823529411764754,
#    'score': 5.8823529411764754,
#    'weight': 5.8823529411764754}),
#  (30,
#   35,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523805,
#    'score': 2.3809523809523805,
#    'weight': 2.3809523809523805}),
#  (30,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5625000000000004,
#    'score': 1.5625000000000004,
#    'weight': 1.5625000000000004}),
#  (30,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.1904761904761902,
#    'score': 1.1904761904761902,
#    'weight': 1.1904761904761902}),
#  (30,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 49.99999999999996,
#    'score': 49.99999999999996,
#    'weight': 49.99999999999996}),
#  (30,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.3809523809523823,
#    'score': 2.3809523809523823,
#    'weight': 2.3809523809523823}),
#  (30,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.4084507042253522,
#    'score': 1.4084507042253522,
#    'weight': 1.4084507042253522}),
#  (30,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.408450704225352,
#    'score': 1.408450704225352,
#    'weight': 1.408450704225352}),
#  (30,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 2.2727272727272725,
#    'score': 2.2727272727272725,
#    'weight': 2.2727272727272725}),
#  (30,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3888888888888893,
#    'score': 1.3888888888888893,
#    'weight': 1.3888888888888893}),
#  (31,
#   32,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.4541622760800839,
#    'score': 1.4541622760800839,
#    'weight': 1.4541622760800839}),
#  (31,
#   33,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.2577319587628868,
#    'score': 1.2577319587628868,
#    'weight': 1.2577319587628868}),
#  (31,
#   34,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 7.6923076923076845,
#    'score': 7.6923076923076845,
#    'weight': 7.6923076923076845}),
#  (31,
#   35,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.53475935828877,
#    'score': 0.53475935828877,
#    'weight': 0.53475935828877}),
#  (31,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.5555555555555555,
#    'score': 0.5555555555555555,
#    'weight': 0.5555555555555555}),
#  (31,
#   37,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.4492753623188404,
#    'score': 1.4492753623188404,
#    'weight': 1.4492753623188404}),
#  (31,
#   38,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.125,
#    'score': 3.125,
#    'weight': 3.125}),
#  (31,
#   39,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 11.30952380952381,
#    'score': 11.30952380952381,
#    'weight': 11.30952380952381}),
#  (31,
#   40,
#   {'count': 2,
#    'label': 'allwords',
#    'median': 17.380952380952444,
#    'score': 17.380952380952444,
#    'weight': 17.380952380952444}),
#  (31,
#   41,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.163660543595711,
#    'score': 1.163660543595711,
#    'weight': 1.163660543595711}),
#  (31,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.7409080641517958,
#    'score': 0.7409080641517958,
#    'weight': 0.7409080641517958}),
#  (31,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.6792984369320246,
#    'score': 0.6792984369320246,
#    'weight': 0.6792984369320246}),
#  (32,
#   33,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 7.530454042081956,
#    'score': 7.530454042081956,
#    'weight': 7.530454042081956}),
#  (32,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7936507936507937,
#    'score': 0.7936507936507937,
#    'weight': 0.7936507936507937}),
#  (32,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.3157894736842102,
#    'score': 1.3157894736842102,
#    'weight': 1.3157894736842102}),
#  (32,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.8958611481975973,
#    'score': 1.8958611481975973,
#    'weight': 1.8958611481975973}),
#  (32,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.439024390243903,
#    'score': 2.439024390243903,
#    'weight': 2.439024390243903}),
#  (32,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 100.0,
#    'score': 100.0,
#    'weight': 100.0}),
#  (32,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.2820512820512817,
#    'score': 1.2820512820512817,
#    'weight': 1.2820512820512817}),
#  (32,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 25.00000000000015,
#    'score': 25.00000000000015,
#    'weight': 25.00000000000015}),
#  (32,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.6493506493506492,
#    'score': 0.6493506493506492,
#    'weight': 0.6493506493506492}),
#  (32,
#   42,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 3.3333333333333335,
#    'score': 6.875000000000008,
#    'weight': 6.875000000000008}),
#  (32,
#   43,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.2838915470494419,
#    'score': 1.2838915470494419,
#    'weight': 1.2838915470494419}),
#  (33,
#   34,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.7518796992481204,
#    'score': 0.7518796992481204,
#    'weight': 0.7518796992481204}),
#  (33,
#   35,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5625,
#    'score': 1.5625,
#    'weight': 1.5625}),
#  (33,
#   36,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.3809523809523823,
#    'score': 2.3809523809523823,
#    'weight': 2.3809523809523823}),
#  (33,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.083333333333334,
#    'score': 2.083333333333334,
#    'weight': 2.083333333333334}),
#  (33,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 14.2857142857143,
#    'score': 14.2857142857143,
#    'weight': 14.2857142857143}),
#  (33,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.8461538461538423,
#    'score': 3.8461538461538423,
#    'weight': 3.8461538461538423}),
#  (33,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.785714285714287,
#    'score': 1.785714285714287,
#    'weight': 1.785714285714287}),
#  (33,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 33.33333333333315,
#    'score': 33.33333333333315,
#    'weight': 33.33333333333315}),
#  (33,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 4.351204351204356,
#    'score': 4.351204351204356,
#    'weight': 4.351204351204356}),
#  (33,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.5873015873015874,
#    'score': 1.5873015873015874,
#    'weight': 1.5873015873015874}),
#  (34,
#   35,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 50.72463768115938,
#    'score': 50.72463768115938,
#    'weight': 50.72463768115938}),
#  (34,
#   36,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 7.6923076923077,
#    'score': 7.6923076923077,
#    'weight': 7.6923076923077}),
#  (34,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.1764705882352942,
#    'score': 1.1764705882352942,
#    'weight': 1.1764705882352942}),
#  (34,
#   38,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 0.7936507936507937,
#    'score': 1.657046657046657,
#    'weight': 1.657046657046657}),
#  (34,
#   39,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 8.698296836982982,
#    'score': 8.698296836982982,
#    'weight': 8.698296836982982}),
#  (34,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.9493946520337952,
#    'score': 0.9493946520337952,
#    'weight': 0.9493946520337952}),
#  (34,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.127659574468085,
#    'score': 2.127659574468085,
#    'weight': 2.127659574468085}),
#  (34,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8333333333333334,
#    'score': 0.8333333333333334,
#    'weight': 0.8333333333333334}),
#  (34,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.8181818181818183,
#    'score': 1.8181818181818183,
#    'weight': 1.8181818181818183}),
#  (35,
#   36,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 14.285714285714272,
#    'score': 11.832611832611834,
#    'weight': 11.832611832611834}),
#  (35,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 6.249999999999995,
#    'score': 6.249999999999995,
#    'weight': 6.249999999999995}),
#  (35,
#   38,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.182071031236628,
#    'score': 1.182071031236628,
#    'weight': 1.182071031236628}),
#  (35,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 20.000000000000036,
#    'score': 20.000000000000036,
#    'weight': 20.000000000000036}),
#  (35,
#   40,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.1363636363636367,
#    'score': 1.1363636363636367,
#    'weight': 1.1363636363636367}),
#  (35,
#   41,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.336956521739131,
#    'score': 2.336956521739131,
#    'weight': 2.336956521739131}),
#  (35,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.067348678601875,
#    'score': 2.067348678601875,
#    'weight': 2.067348678601875}),
#  (35,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 5.263157894736845,
#    'score': 5.263157894736845,
#    'weight': 5.263157894736845}),
#  (36,
#   37,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (36,
#   38,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 1.7450271247739606,
#    'score': 1.7450271247739606,
#    'weight': 1.7450271247739606}),
#  (36,
#   39,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (36,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 7.752613240418112,
#    'score': 7.752613240418112,
#    'weight': 7.752613240418112}),
#  (36,
#   41,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.3138297872340425,
#    'score': 2.3138297872340425,
#    'weight': 2.3138297872340425}),
#  (36,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 2.6675341574495772,
#    'score': 2.6675341574495772,
#    'weight': 2.6675341574495772}),
#  (36,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 8.333333333333346,
#    'score': 8.333333333333346,
#    'weight': 8.333333333333346}),
#  (37,
#   38,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.439024390243903,
#    'score': 2.439024390243903,
#    'weight': 2.439024390243903}),
#  (37,
#   39,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.234567901234568,
#    'score': 1.234567901234568,
#    'weight': 1.234567901234568}),
#  (37,
#   40,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 99.99999999999991,
#    'score': 99.99999999999991,
#    'weight': 99.99999999999991}),
#  (37,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 7.6923076923076845,
#    'score': 7.6923076923076845,
#    'weight': 7.6923076923076845}),
#  (37,
#   42,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 51.42857142857143,
#    'score': 51.42857142857143,
#    'weight': 51.42857142857143}),
#  (37,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 14.2857142857143,
#    'score': 14.2857142857143,
#    'weight': 14.2857142857143}),
#  (38,
#   39,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.6174957118353345,
#    'score': 0.6174957118353345,
#    'weight': 0.6174957118353345}),
#  (38,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 0.9763660744217229,
#    'score': 0.9763660744217229,
#    'weight': 0.9763660744217229}),
#  (38,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 0.8474576271186439,
#    'score': 0.8474576271186439,
#    'weight': 0.8474576271186439}),
#  (38,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.666666666666693,
#    'score': 16.666666666666693,
#    'weight': 16.666666666666693}),
#  (38,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.3513513513513518,
#    'score': 1.3513513513513518,
#    'weight': 1.3513513513513518}),
#  (39,
#   40,
#   {'count': 2,
#    'label': 'verbs',
#    'median': 6.852409638554212,
#    'score': 6.852409638554212,
#    'weight': 6.852409638554212}),
#  (39,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.439024390243902,
#    'score': 2.439024390243902,
#    'weight': 2.439024390243902}),
#  (39,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 1.1627906976744187,
#    'score': 1.1627906976744187,
#    'weight': 1.1627906976744187}),
#  (39,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 3.3333333333333335,
#    'score': 3.3333333333333335,
#    'weight': 3.3333333333333335}),
#  (40,
#   41,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 2.3809523809523823,
#    'score': 2.3809523809523823,
#    'weight': 2.3809523809523823}),
#  (40,
#   42,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 24.99999999999998,
#    'score': 24.99999999999998,
#    'weight': 24.99999999999998}),
#  (40,
#   43,
#   {'count': 1,
#    'label': 'allwords',
#    'median': 0.8928571428571429,
#    'score': 0.8928571428571429,
#    'weight': 0.8928571428571429}),
#  (41,
#   42,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 16.66666666666665,
#    'score': 16.66666666666665,
#    'weight': 16.66666666666665}),
#  (41,
#   43,
#   {'count': 1,
#    'label': 'verbs',
#    'median': 1.6949152542372885,
#    'score': 1.6949152542372885,
#    'weight': 1.6949152542372885}),
#  (42,
#   43,
#   {'count': 3,
#    'label': 'verbs',
#    'median': 2.7777777777777795,
#    'score': 6.200651200651207,
#    'weight': 6.200651200651207})]

# %%
nx.write_gexf(g, 'files/verb_output/docs_only_verb_edges_too.gexf')

# %% [markdown]
# #### You can look at the gexf in gephi, but there's an issue with labels on edges not behaving correctly. So let's do some d3.

# %%
from networkx.readwrite import json_graph

# %%
import json
g_json = json_graph.node_link_data(g) # node-link format to serialize
json.dump(g_json, open('files/verb_output/network_with_verbs.json','w'))
